# %%
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/My\ Drive/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento/
# Out:
# /content/gdrive/.shortcut-targets-by-id/13aHaot6tbm7SROiS_JzQgfDtjZ_DM4PH/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento

# %%
# !ls /content/gdrive/My\ Drive/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento/00_Dataset_Cortadas_Redimensionadas_perros/*

# %%
# -----------------------------------------------------  Eigenfaces versus Fisherfaces on the Faces94 Database with Scikit-Learn  --------#
#---------- https://nicholastsmith.wordpress.com/2016/02/18/eigenfaces-versus-fisherfaces-on-the-faces94-database-with-scikit-learn/ ----#
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA
from random import randint
import matplotlib.cm as cm
from skimage import io, color
import os
import cv2

path_fisher='FISHER_PRUEBAS' #4

# %% Leer las imagenes

#Cantidad de imagenes por sujetos
numImg = 3
#Numero de sujetos (Perros)
numSbj = 50
#Matriz de ceros con dimensiones (240, 36000)
A = np.zeros([numImg * numSbj, 180 * 180])
#Matriz de ceros con dimensiones (240,)
y = np.zeros([numImg * numSbj])

#Path de la carpeta de imagenes
#fPath = path_redicortadas
fPath = '00_Dataset_Cortadas_Redimensionadas_perros'

#Se le asigna el numero de sujetos a recorrer
j = numSbj

#Iterador del total de las imagenes (numImg * numSbj)
c = 0

#For que recorre las carpetas(sujetos) del path
for i in os.listdir(fPath):
    if(j <= 0):
        break
    j -= 1
    
    #For que recorre la imagen de cada carpeta(sujeto)
    for f in os.listdir(fPath + '/' + i):
      
      #i Carpeta del sujeto 
      #f Nombre de la imagen del sujeto
      #Ruta de la imagen
      imgPath = fPath + '/' + i + '/' + f
      #A[Y,X]
      #Se lee por cada c(fila de la matriz), todas las columnas de la misma
      A[c, :] = color.rgb2gray(io.imread(imgPath)).reshape([1, 180 * 180])
      #Se crea un arreglo con la cantida de imagenes que hay por sujeto. Identificandp a cada sujeto(j)
      y[c] = j
      c = c + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-c54bee0b6099> in <module>()
#      51       #A[Y,X]
#      52       #Se lee por cada c(fila de la matriz), todas las columnas de la misma
# ---> 53       A[c, :] = color.rgb2gray(io.imread(imgPath)).reshape([1, 180 * 180])
#      54       #Se crea un arreglo con la cantida de imagenes que hay por sujeto. Identificandp a cada sujeto(j)
#      55       y[c] = j
#
# IndexError: index 60 is out of bounds for axis 0 with size 60

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA
from random import randint
import matplotlib.cm as cm
from skimage import io, color
import os
import cv2


#Cantidad de imagenes por sujetos
numImg = 3
#Numero de sujetos (Perros)
numSbj = 50
#Matriz de ceros con dimensiones (240, 36000)
A = np.zeros([numImg * numSbj, 180 * 180])
#Matriz de ceros con dimensiones (240,)
y = np.zeros([numImg * numSbj])

#Se le asigna el numero de sujetos a recorrer
j = numSbj

#Iterador del total de las imagenes (numImg * numSbj)
c = 0

path_redimensionadas='00_Dataset_Cortadas_Redimensionadas_perros' #4
path_resultado='FISHER_PRUEBAS' #4


#Array para apilar las imagenes
files = [] #nombre de las imagenes
path_files = [] #nombre de las carpetas por cantidad de imagenes
path_database = [] #contiene la ruta de cada imagen
array_imagenes =[] #matrices que representan cada imagen
#####---------------------------
#For que recorre las carpetas(sujetos) del path
contador = 0
for aa in os.listdir(path_redimensionadas):
    #For que recorre la imagen de cada carpeta(sujeto)
    max_num=0;
    for f in os.listdir(path_redimensionadas + '/' + aa):
      max_num=max_num+1
    #For que recorre la imagen de cada carpeta(sujeto)
    if(max_num>3):
      contador = contador + 1
      if(contador<=(50)):
        path_files.append(aa)
        max_numImg=0;
        for f in os.listdir(path_redimensionadas + '/' + aa):
          if(max_numImg<3):
            #aa Carpeta del sujeto 
            #f Nombre de la imagen del sujeto
            #Ruta de la imagen
            imgPath = path_redimensionadas + '/' + aa + '/' + f
            files.append(f)
            path_database.append(imgPath)

            #A[Y,X]
            #Se lee por cada c(fila de la matriz), todas las columnas de la misma
            #A[c, :] = color.rgb2gray(io.imread(imgPath)).reshape([1, 180 * 180])
            #Se crea un arreglo con la cantida de imagenes que hay por sujeto. Identificandp a cada sujeto(j)
            #y[c] = j
            #c = c + 1
            max_numImg=max_numImg+1
      

print("path_files", files);
print("# path_files", len(files));
print("path_database", path_files);
print("path_database", len(path_files));
# Out:
# path_files ['1.jpeg', '3.jpeg', '5.jpeg', 'Bandit__06-crp.png', 'Bandit__07-crp.png', 'Bandit__13-crp.png', 'Apolo__08-crp.png', 'Apolo__07-crp.png', 'Apolo__09-crp.png', 'Bella-Kappel__05-crp.png', 'Bella-Kappel__09-crp.png', 'Bella-Kappel__03-crp.png', 'Bailey__02-crp.png', 'Bailey__03-crp.png', 'Bailey__04-crp.png', 'Bella__05-crp.png', 'Bella__02-crp.png', 'Bella__08-crp.png', 'Bella-Theresa__02-crp.png', 'Bella-Theresa__01-crp.png', 'Bella-Theresa__06-crp.png', 'Dakota__11-crp.png', 'Dakota__04-crp.png', 'Dakota__05-crp.png', 'Clara__09-crp.png', 'Clara__04-crp.png', 'Clara__05-crp.png', 'Bu-chan__06-crp.png', 'Bu-chan__01-crp.png', 'Bu-chan__03-crp.png', '1.jpeg', '2.jpeg', '3.jpeg', '1.jpeg', '2.jpeg', '3.jpeg', 'Dakota-CNC__01-crp.png', 'Dakota-CNC__03-crp.png', 'Dakota-CNC__04-crp.png', 'Doris__07-crp.png', 'Doris__04-crp.png', 'Doris__03-crp.png', 'WhatsApp Image 2020-04-18 at 2.19.01 PM.jpeg', 'WhatsApp Image 2020-04-18 at 2.19.00 PM (1).jpeg', 'WhatsApp Image 2020-04-18 at 2.19.00 PM (2).jpeg', '1.jpeg', '1(1).jpeg', '2.jpeg', 'Injun__02-crp.png', 'Injun__05-crp.png', 'Injun__01-crp.png', 'Duke__03-crp.png', 'Duke__02-crp.png', 'Duke__01-crp.png', '1.jpeg', '3.jpeg', '4.jpeg', '2.jpeg', '3.jpeg', '4.jpeg', '1.jpeg', '2.jpeg', '3.jpeg', 'Eve__03-crp.png', 'Eve__01-crp.png', 'Eve__04-crp.png', 'Gracie__03-crp.png', 'Gracie__12-crp.png', 'Gracie__01-crp.png', 'Kira__01-crp.png', 'Kira__03-crp.png', 'Kira__02-crp.png', 'Landy__04-crp.png', 'Landy__07-crp.png', 'Landy__01-crp.png', 'Koda__01-crp.png', 'Koda__03-crp.png', 'Koda__02-crp.png', 'Lulu__08-crp.png', 'Lulu__04-crp.png', 'Lulu__06-crp.png', '4.jpeg', '5.jpeg', '8.jpeg', 'Meeshka__13-crp.png', 'Meeshka__10-crp.png', 'Meeshka__01-crp.png', '13.jpeg', '14.jpeg', '15.jpeg', '1.jpeg', '2.jpeg', '5.jpeg', 'Monty__06-crp.png', 'Monty__10-crp.png', 'Monty__05-crp.png', 'Nikita__01-crp.png', 'Nikita__04-crp.png', 'Nikita__02-crp.png', 'Noodles__03-crp.png', 'Noodles__01-crp.png', 'Noodles__09-crp.png', 'Newton__01-crp.png', 'Newton__03-crp.png', 'Newton__04-crp.png', '93777729_162378115089670_4292660608076840341_n.jpg', '94291771_245031853355895_6192519569420489614_n.jpg', '93398299_135872321339655_6315346296484756015_n.jpg', 'Peaches__07-crp.png', 'Peaches__03-crp.png', 'Peaches__04-crp.png', 'Oliver__05-crp.png', 'Oliver__03-crp.png', 'Oliver__04-crp.png', '1.jpeg', '2.jpeg', '3.jpeg', '1.jpeg', '4.jpeg', '5.jpeg', 'Rave__07-crp.png', 'Rave__02-crp.png', 'Rave__04-crp.png', '1.jpeg', '3.jpeg', '6.jpeg', 'Rico__01-crp.png', 'Rico__03-crp.png', 'Rico__04-crp.png', 'Ridley__02-crp.png', 'Ridley__01-crp.png', 'Ridley__03-crp.png', 'Roscoe__08-crp.png', 'Roscoe__03-crp.png', 'Roscoe__02-crp.png', 'Purcy__01-crp.png', 'Purcy__05-crp.png', 'Purcy__12-crp.png', 'Skye__01-crp.png', 'Skye__04-crp.png', 'Skye__02-crp.png', 'Skipper__03-crp.png', 'Skipper__02-crp.png', 'Skipper__04-crp.png', 'Winston__04-crp.png', 'Winston__01-crp.png', 'Winston__03-crp.png', '1.jpg', '2.jpg', '3.jpg']
# # path_files 150
# path_database ['American Bully-Yoko', 'Bandit - Pug', 'Apolo - Husky', 'Bella-Kappel - Husky', 'Bailey - Husky', 'Bella - Husky', 'Bella-Theresa - Husky', 'Dakota - Husky', 'Clara - Pug', 'Bu-chan - Pug', 'Canela - Criollo', 'Dante - Mixto', 'Dakota-CNC- Husky', 'Doris - Pug', 'Dina-Border Collie', 'Husky-Jonva', 'Injun - Husky', 'Duke - Pug', 'Eimmy-Beagle', 'Dulce - Boxer', 'Goliath - Bulldog Ingles', 'Eve - Husky', 'Gracie - Pug', 'Kira - Husky', 'Landy - Husky', 'Koda- Husky', 'Lulu - Husky', 'Mardi - Pinscher', 'Meeshka - Husky', 'Mickey - Beagle', 'Nala2-Criollo', 'Monty2 - Pug', 'Nikita - Pug', 'Noodles - Pug', 'Newton - Pug', 'Paimei - Mixto', 'Peaches - Pug', 'Oliver - Pug', 'Oreo - Chitzu', 'Orion - Gran Danes', 'Rave - Husky', 'Santa - Criollo', 'Rico - Pug', 'Ridley - Pug', 'Roscoe - Pug', 'Purcy - Pug', 'Skye - Husky', 'Skipper - Husky', 'Winston - Pug', 'Tony - Criollo']
# path_database 50

# %%
plt.figure()
pca = PCA(n_components=3)
pca.fit(A)
for i in range(2):
    ax = plt.subplot(2, 2, i + 1)
    ax.imshow(pca.components_[i].reshape([180, 180]),cmap='Greys')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/_pca.py:545: RuntimeWarning: invalid value encountered in true_divide
#   self.explained_variance_ / total_var.sum()

# %%
#Colors for distinct individuals
cols = ['#{:06x}'.format(randint(0, 0xffffff)) for i in range(numSbj)]
pltCol = [cols[int(k)] for k in y]
# %% Plot 2d PCA data
drA = pca.transform(A)
plt.figure()
plt.scatter(drA[:, 0], drA[:, 1], color=pltCol)
plt.show()

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
#---Fisherfaces Based Classification

# %%Compute Fisherfaces
lda = LinearDiscriminantAnalysis()
#kf = KFold(n_splits=2)
kf = KFold(n_splits=4, random_state=1, shuffle=True)
kf.get_n_splits(A)

print(kf)

for train_index, test_index in kf.split(A):
  #print("TRAIN:", train_index, "TEST:", test_index)
  X_train, X_test = A[train_index], A[test_index]
  y_train, y_test = y[train_index], y[test_index]
  #Use PCA to transform from dimension F to dimension N-m
  pca = PCA(n_components=(len(train_index) - numSbj))
  pca.fit(A[train_index])
  #Compute LDA of reduced data
  lda.fit(pca.transform(A[train_index]), y[train_index])
  yHat = lda.predict(pca.transform(A[test_index]))
  #Compute classification error
  outVal = accuracy_score(y_test, yHat)
  print('Score: ' + str(outVal*100))
# Out:
# KFold(n_splits=4, random_state=1, shuffle=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/_pca.py:545: RuntimeWarning: invalid value encountered in true_divide
#   self.explained_variance_ / total_var.sum()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-89f01f2a35b1> in <module>()
#      21   pca.fit(A[train_index])
#      22   #Compute LDA of reduced data
# ---> 23   lda.fit(pca.transform(A[train_index]), y[train_index])
#      24   yHat = lda.predict(pca.transform(A[test_index]))
#      25   #Compute classification error
#
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py in fit(self, X, y)
#     475             if self.shrinkage is not None:
#     476                 raise NotImplementedError('shrinkage not supported')
# --> 477             self._solve_svd(X, y)
#     478         elif self.solver == 'lsqr':
#     479             self._solve_lsqr(X, y, shrinkage=self.shrinkage)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py in _solve_svd(self, X, y)
#     394         # Use SVD to find projection in the space spanned by the
#     395         # (n_classes) centers
# --> 396         _, S, V = linalg.svd(X, full_matrices=0)
#     397
#     398         self.explained_variance_ratio_ = (S**2 / np.sum(
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/decomp_svd.py in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     123     # compute optimal lwork
#     124     lwork = _compute_lwork(gesXd_lwork, a1.shape[0], a1.shape[1],
# --> 125                            compute_uv=compute_uv, full_matrices=full_matrices)
#     126
#     127     # perform decomposition
#
# /usr/local/lib/python3.6/dist-packages/scipy/linalg/lapack.py in _compute_lwork(routine, *args, **kwargs)
#     804     """
#     805     dtype = getattr(routine, 'dtype', None)
# --> 806     ret = routine(*args, **kwargs)
#     807     if ret[-1] != 0:
#     808         raise ValueError("Internal work array size computation failed: "
#
# ValueError: On entry to DGESDD parameter number 10 had an illegal value

# %%
# %% Fit all data for plots
pca = PCA(n_components=(len(A) - numSbj))
pca.fit(A)
pcatA = pca.transform(A)
lda.fit(pcatA, y)
ldatA = lda.transform(pcatA)
#Plot fisherfaces
plt.figure()
for i in range(6):
    ax = plt.subplot(2, 3, i + 1)
    #Map from PCA space back to the original space (of images)
    C1 = pca.inverse_transform(lda.scalings_[:, i])
    C1.shape = [180, 180]
    ax.imshow(C1,cmap='Greys')
plt.show()

for i in range(10):
    #Guarda imagenes imagenes con cuadros
    os.makedirs(path_fisher, exist_ok=True)
    filename=(path_fisher + '/' + "PRUEBA_" + i + ".jpg") 
    cv2.imwrite(filename, C1)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:399: RuntimeWarning: invalid value encountered in true_divide
#   S**2))[:self._max_components]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-fd5932d4a0f2> in <module>()
#      10     ax = plt.subplot(2, 3, i + 1)
#      11     #Map from PCA space back to the original space (of images)
# ---> 12     C1 = pca.inverse_transform(lda.scalings_[:, i])
#      13     C1.shape = [180, 180]
#      14     ax.imshow(C1,cmap='Greys')
#
# IndexError: index 0 is out of bounds for axis 1 with size 0

# %%
# %% simplified LDA
kf = KFold(n_splits=4, random_state=1, shuffle=True)
kf.get_n_splits(A)

print(kf)

for train_index, test_index in kf.split(A):
  #print("TRAIN:", train_index, "TEST:", test_index)
  X_train, X_test = A[train_index], A[test_index]
  y_train, y_test = y[train_index], y[test_index]
  #Compute LDA of reduced data
  lda.fit(X_train, y_train)
  #Compute classification error
  outVal = lda.score(X_test, y_test)
  print('Score: ' + str(outVal*100))
