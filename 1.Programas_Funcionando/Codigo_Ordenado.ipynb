# %% [markdown]
# *** PREPROCESAMIENTO ***

# %% [markdown]
# Datos del Drive.
# 1. Conexión y permisos con el drive personal

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 2. Ubicación de las carpetas a utilizar

# %%
#%cd /content/gdrive/My Drive/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento/
# %cd /content/gdrive/My Drive/0_Desarrollo_Tesis/
# Out:
# /content/gdrive/My Drive/0_Desarrollo_Tesis

# %% [markdown]
# 3. Listar la lista del contenido de la ruta

# %%
# !ls /content/gdrive/My\ Drive/0_Desarrollo_Tesis/*
# Out:
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/0.Detector Convolucional':
# dogHeadDetector.dat
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/10. Documentación':
#  Cronogramas   Documento  'Investigación de Temas'
#  Dialogos      Guias	   Links.docx
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/11.Presentaciones':
# 'Conceptos Web.pptx'   Invarianza.pptx	 Tesis
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/1.Programas_Funcionando':
#  Codigo_Ordenado.ipynb		        Fisher.ipynb
# 'Copia de distancia_euclidiana.ipynb'   LBPH.ipynb
#  distancia_euclidiana.ipynb	        Preprocesamiento_ENTRADA
#  Eigen.ipynb			        Preprocesamiento.ipynb
#  euclidean_distance.ipynb	        Renombrar_imagenes.ipynb
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento':
# Buscar_gato  Buscar_perro  Gatos  Perros
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/3.Datasets':
#  1.DATASET_PERROS   '3. DATASET_ENTRADA_PERROS'
# '2. DATESET_GATOS'  '4. DATASET_ENTRADA_GATOS'
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/4. Procesamiento':

# %% [markdown]
# Resultados del preprocesamiento son las siguientes carpetas:
#
#
# 1.   NO_DETECTADAS: En esta carpeta se ubicaran las imagenes la cuales no se detecta la parte facial del perro/gato.
# 2.   DETECTADAS: En esta carpeta se ubicaran las imagenes que fueron detectadas y donde se señala la parte facial del perro/gato.
# 3.   ROSTRO_REDIMENSIONADO: En esta carpeta se ubicaran las imagenes que contienen unicamente la región del rostro del perro/gato. Las guarda en una dimension (180 x 180) y formato .png

# %%
# Importar Librerias

import dlib, cv2, os
from imutils import face_utils
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def menu_tesis():
   print("----------- Tesis U Catolica -----------")
   print("1. Perros")
   print("2. Buscar Perro")
   print("3. Gatos")
   print("4. Buscar Gato")
   print("-----------------------------------")

# %%
def seleccion_opcion():
  menu_tesis()
  opcion = int(input("Seleccione una opcion: "))
  caso_opcion(opcion)

# %%
def preprocesamiento_imagen(path_DATASET,path_DETECTADAS,path_NO_DETECTADAS,path_ROSTRO_REDIMENSIONADO):
  cont_imagen=0
  #For que recorre las carpetas(sujetos) del path_DATASET
  for cj in os.listdir(path_DATASET):
      
      #For que recorre la imagen de cada carpeta(sujeto)
      for nj in os.listdir(path_DATASET + '/' + cj):

        cont_imagen=cont_imagen+1
        #-------------
        #cj   -> Carpeta del sujeto 
        #nj   -> Nombre de la imagen del sujeto
        #path_DATASET -> Ruta de la imagen
        imgPath = path_DATASET + '/' + cj + '/' + nj
        #-------------
      
        #Abrir Imagen (Lee la imagen en formtado BGR)
        imgBGR = cv2.imread(imgPath)
        #print(imgPath)
        #print(imgBGR)
        print(cj)
        print(nj)
        height, width, channels = imgBGR.shape
        #print("|---Imagen de entrada----|")
        #print ("Alto: ",height," Ancho: ", width,"Canales: ", channels)
        #print ("Resultado", height*width)
        total=(height*width)

        #Cambiar el tamaño resize
        if(total>=1310720):
          height = 700
          width = 700
          dim = (width, height)
          imgBGR = cv2.resize(imgBGR, dim, interpolation=cv2.INTER_LINEAR)

        #Convierte la imagen en RGB
        imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)

        #Copiar imagen del formato RGB para luego convertirla en GRAY
        imgcopyBGR_cortar = np.copy(imgBGR)
        imgcopyBGR_cuadros = np.copy(imgBGR)

        #Nombre y extension
        filename, ext = os.path.splitext(os.path.basename(imgPath))

        #Copiar imagen del formato RGB para luego convertirla en GRAY
        imgcopyRGB = np.copy(imgRGB)
        # Se convierte a escala de grises 
        imgGRAY = cv2.cvtColor(imgcopyRGB, cv2.COLOR_RGB2GRAY)

        
        #--------------------------------------------------------------
        #Detector de Cara
        #https://github.com/kairess/dog_face_detector
        detector = dlib.cnn_face_detection_model_v1('0.Detector Convolucional/dogHeadDetector.dat')
        dets = detector(imgGRAY, upsample_num_times=1)


        #print("Cantidad de caras encontradas en la Imagen->",len(dets))

        if (len(dets)==0):
            #print ("Error: No se detectaron caras en la imagen: ", imgi)
            #Guarda imagenes imagenes NO ENCONTRADAS
            os.makedirs(path_NO_DETECTADAS+ '/'+ cj, exist_ok=True)
            filename=(path_NO_DETECTADAS+ '/' + cj + '/' + nj ) 
            #print(filename)
            cv2.imwrite(filename, imgBGR) 
        else:

          #Recorre el número de caras encontradas
          for i, d in enumerate(dets):

              #print("Detection {}: Left: {} Top: {} Right: {} Bottom: {} Confidence: {}".format(i, d.rect.left(), d.rect.top(), d.rect.right(), d.rect.bottom(), d.confidence))

              x, y = d.rect.left(), d.rect.top()
              x2, y2 = d.rect.right(), d.rect.bottom()
              #alto
              h=x2-x
              #ancho
              w=y2-y
              # representa la esquina superior izquierda del rectángulo PT1
              # representa la esquina inferior izquierda del rectángulo PT2
              # Color (255,0,0) en RGB
              # Grosor de línea thickness
              # Se usa el método cv2.rectangle () para dibujar un rectángulo
              cv2.rectangle(imgcopyBGR_cuadros, pt1=(x, y), pt2=(x2, y2), thickness=2, color=(255, 0, 0), lineType=cv2.LINE_AA)

              #Se valida si las coordenadas son negativas para dejar en cero por defecto
              if y<0:
                  y=0
              if x<0:
                  x=0
              if h<0:
                  h=0
              if w<0:
                  w=0

              #Corta y guarda imagenes
              # Crear la carpeta si no esta creada 
              os.makedirs(path_ROSTRO_REDIMENSIONADO+ '/'+cj, exist_ok=True)
              filename=(path_ROSTRO_REDIMENSIONADO+ '/' + cj + '/' + nj) 
              #Ejemplo: image[y:y+h, x:x+w]
              cropped_image=imgcopyBGR_cortar[y:(y+h), x:(x+w)]
              #Cambiar el tamaño resize
              height = 180
              width = 180
              dim = (width, height)
              cropped_image = cv2.resize(cropped_image, dim, interpolation=cv2.INTER_LINEAR)
              cv2.imwrite(filename, cropped_image) 
          #--------------------------------------------------------------

          
          #Guarda imagenes imagenes con cuadros
          os.makedirs(path_DETECTADAS+ '/'+cj, exist_ok=True)
          filename=(path_DETECTADAS+ '/' + cj + '/' + nj) 
          cv2.imwrite(filename, imgcopyBGR_cuadros) 

  print("TERMINO !!")
  print("Cantidad de imagenes ", cont_imagen)

  #plt.figure(figsize=(16, 16))
  #plt.imshow(imgcopyBGR_cuadros)

# %%
def caso_opcion(opcion):
  if opcion == 1:
    print('Perros')
    path_DATASET = '3.Datasets/1.DATASET_PERROS' #1
    path_DETECTADAS='2.Resultados_Preprocesamiento/Perros/DETECTADAS' #2
    path_NO_DETECTADAS='2.Resultados_Preprocesamiento/Perros/NO_DETECTADAS' #3
    path_ROSTRO_REDIMENSIONADO='2.Resultados_Preprocesamiento/Perros/ROSTRO_REDIMENSIONADO' #4
    preprocesamiento_imagen(path_DATASET,path_DETECTADAS,path_NO_DETECTADAS,path_ROSTRO_REDIMENSIONADO)
  elif opcion == 2:
    print('Buscar Perro')
    path_DATASET = '3.Datasets/3.DATASET_ENTRADA_PERROS' #1
    path_DETECTADAS='2.Resultados_Preprocesamiento/Buscar_perro/DETECTADAS' #2
    path_NO_DETECTADAS='2.Resultados_Preprocesamiento/Buscar_perro/NO_DETECTADAS' #3
    path_ROSTRO_REDIMENSIONADO='2.Resultados_Preprocesamiento/Buscar_perro/ROSTRO_REDIMENSIONADO' #4
    preprocesamiento_imagen(path_DATASET,path_DETECTADAS,path_NO_DETECTADAS,path_ROSTRO_REDIMENSIONADO)
  elif opcion == 3:
    print('Gatos')
    path_DATASET = '3.Datasets/2.DATASET_GATOS' #1
    path_DETECTADAS='2.Resultados_Preprocesamiento/Gatos/DETECTADAS' #2
    path_NO_DETECTADAS='2.Resultados_Preprocesamiento/Gatos/NO_DETECTADAS' #3
    path_ROSTRO_REDIMENSIONADO='2.Resultados_Preprocesamiento/Gatos/ROSTRO_REDIMENSIONADO' #4
    preprocesamiento_imagen(path_DATASET,path_DETECTADAS,path_NO_DETECTADAS,path_ROSTRO_REDIMENSIONADO)
  elif opcion == 4:
    print('Buscar Gato')
    path_DATASET = '3.Datasets/4.DATASET_ENTRADA_GATOS' #1
    path_DETECTADAS='2.Resultados_Preprocesamiento/Buscar_gato/DETECTADAS' #2
    path_NO_DETECTADAS='2.Resultados_Preprocesamiento/Buscar_gato/NO_DETECTADAS' #3
    path_ROSTRO_REDIMENSIONADO='2.Resultados_Preprocesamiento/Buscar_gato/ROSTRO_REDIMENSIONADO' #4
    preprocesamiento_imagen(path_DATASET,path_DETECTADAS,path_NO_DETECTADAS,path_ROSTRO_REDIMENSIONADO)
  else:
    #seleccion_opcion()
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    print('Error: La opción ingresada no esta dentro de las opciones, por favor vuelva a ingresar la opción')
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    print('')
    print('')
    print('')
    seleccion_opcion()

seleccion_opcion()
# Out:
# ----------- Tesis U Catolica -----------
# 1. Perros
# 2. Buscar Perro
# 3. Gatos
# 4. Buscar Gato
# -----------------------------------
# Seleccione una opcion: 3
# Gatos
# Cat - Persa
# 1.jpeg
# Cat - Persa
# 2.jpeg
# Cat - Persa
# 3.jpeg
# Cat - Persa
# 4.jpeg
# Cat - Persa
# 5.jpeg
# Celestina - Criollo
# 1.jpeg
# Celestina - Criollo
# 2.jpeg
# Celestina - Criollo
# 3.jpeg
# Celestina - Criollo
# 4.jpeg
# Lola - Criollo
# 1.jpeg
# Lola - Criollo
# 2.jpeg
# Lola - Criollo
# 3.jpeg
# Lola - Criollo
# 4.jpeg
# Lola - Criollo
# 5.jpeg
# Lola - Criollo
# 6.jpeg
# Lola - Criollo
# 7.jpeg
# Lola - Criollo
# 8.jpeg
# Lola - Criollo
# 9.jpeg
# Lola - Criollo
# 10.jpeg
# Lola - Criollo
# 11.jpeg
# Lola - Criollo
# 12.jpeg
# Lola - Criollo
# 13.jpeg
# Lola - Criollo
# 14.jpeg
# Lola - Criollo
# 15.jpeg
# Lola - Criollo
# 16.jpeg
# Lola - Criollo
# 17.jpeg
# Lola - Criollo
# 18.jpeg
# Lola - Criollo
# 19.jpeg
# Kira - Criollo
# 1.jpeg
# Kira - Criollo
# 2.jpeg
# Kuroneko - Criollo
# 3.jpeg
# Kuroneko - Criollo
# 4.jpeg
# Kuroneko - Criollo
# 1.jpeg
# Kuroneko - Criollo
# 2.jpeg
# Kuroneko - Criollo
# 5.jpeg
# Lupita - Criollo
# 1.jpeg
# Lupita - Criollo
# 2.jpeg
# Lupita - Criollo
# 3.jpeg
# Lupita - Criollo
# 4.jpeg
# Lupita - Criollo
# 5.jpeg
# Lupita - Criollo
# 6.jpeg
# Lupita - Criollo
# 7.jpeg
# Lupita - Criollo
# 8.jpeg
# Lupita - Criollo
# 9.jpeg
# Lupita - Criollo
# 10.jpeg
# Luna - Criollo
# 1.jpeg
# Luna - Criollo
# 2.jpeg
# Luna - Criollo
# 3.jpeg
# Luna - Criollo
# 4.jpeg
# Ramon - Criollo
# 1.jpeg
# Ramon - Criollo
# 2.jpeg
# Ramon - Criollo
# 3.jpeg
# Ramon - Criollo
# 4.jpeg
# Serena- Atigrado
# 1.jpeg
# Serena- Atigrado
# 2.jpeg
# Serena- Atigrado
# 3.jpeg
# Serena- Atigrado
# 4.jpeg
# Serena- Atigrado
# 5.jpeg
# Serena- Atigrado
# 6.jpeg
# Serena- Atigrado
# 7.jpeg
# Serena- Atigrado
# 8.jpeg
# Nala - Angora
# 1.jpeg
# Nala - Angora
# 2.jpeg
# Nala - Angora
# 3.jpeg
# Nala - Angora
# 4.jpeg
# Nala - Angora
# 5.jpeg
# Nala - Angora
# 6.jpeg
# Milly-Carey
# 1.jpeg
# Milly-Carey
# 2.jpeg
# Milly-Carey
# 3.jpeg
# Milly-Carey
# 4.jpeg
# Milly-Carey
# 5.jpeg
# Milly-Carey
# 6.jpeg
# Milly-Carey
# 7.jpeg
# Milly-Carey
# 8.jpeg
# Milly-Carey
# 9.jpeg
# Milly-Carey
# 10.jpeg
# Milly-Carey
# 11.jpeg
# Milly-Carey
# 12.jpeg
# Milly-Carey
# 14.jpeg
# Nala - Criollo
# 1.jpeg
# Nala - Criollo
# 2.jpeg
# Nala - Criollo
# 3.jpeg
# Nala - Criollo
# 4.jpeg
# Nala - Criollo
# 5.jpeg
# Nala - Criollo
# 6.jpeg
# Tom - Criollo
# 1.jpeg
# Tom - Criollo
# 2.jpeg
# Tom - Criollo
# 3.jpeg
# Tom - Criollo
# 4.jpeg
# Hassa - Criollo
# 1.jpeg
# Hassa - Criollo
# 2.jpeg
# Hassa - Criollo
# 3.jpeg
# Isis - Criollo
# 1.jpeg
# Isis - Criollo
# 2.jpeg
# Isis - Criollo
# 3.jpeg
# Janny - Criollo
# 1.jpeg
# Janny - Criollo
# 2.jpeg
# Janny - Criollo
# 3.jpeg
# Narciso - Criollo
# 1.jpeg
# Narciso - Criollo
# 2.jpeg
# Narciso - Criollo
# 3.jpeg
# Gasper - Criollo
# 1.jpeg
# Gasper - Criollo
# 2.jpeg
# Gasper - Criollo
# 3.jpeg
# Gasper - Criollo
# 4.jpeg
# Gasper - Criollo
# 5.jpeg
# Aron - Criollo
# 1.jpeg
# Aron - Criollo
# 2.jpeg
# Aron - Criollo
# 3.jpeg
# Manny - Criollo
# 1.jpeg
# Manny - Criollo
# 2.jpeg
# Manny - Criollo
# 3.jpeg
# Teo - Criollo
# 1.jpeg
# Teo - Criollo
# 2.jpeg
# Teo - Criollo
# 3.jpeg
# Suzy - criollo
# 1.jpeg
# Suzy - criollo
# 2.jpeg
# Suzy - criollo
# 3.jpeg
# Tito - Pixie Bob
# 1.jpeg
# Tito - Pixie Bob
# 2.jpeg
# Tito - Pixie Bob
# 3.jpeg
# Felix - Criollo
# 1.jpeg
# Felix - Criollo
# 2.jpeg
# Felix - Criollo
# 3.jpeg
# Felix - Criollo
# 4.jpeg
# Mono - Criollo
# 1.jpeg
# Mono - Criollo
# 2.jpeg
# Mono - Criollo
# 3.jpeg
# Mono - Criollo
# 4.jpeg
# Mono - Criollo
# 5.jpeg
# Mono - Criollo
# 6.jpeg
# Mono - Criollo
# 7.jpeg
# Cidron - Criollo
# 1.jpeg
# Cidron - Criollo
# 2.jpeg
# Cidron - Criollo
# 3.jpeg
# Mia - Criollo
# 1.jpeg
# Mia - Criollo
# 2.jpeg
# Mia - Criollo
# 3.jpeg
# Mia - Criollo
# 4.jpeg
# Bambino - Criollo
# 1.jpeg
# Bambino - Criollo
# 2.jpeg
# Bambino - Criollo
# 3.jpeg
# Bambino - Criollo
# 4.jpeg
# Bambino - Criollo
# 5.jpeg
# Arenita - Carey
# 1.jpeg
# Arenita - Carey
# 2.jpeg
# Arenita - Carey
# 3.jpeg
# Batman - Criollo
# 1.jpeg
# Batman - Criollo
# 2.jpeg
# Batman - Criollo
# 3.jpeg
# Batman - Criollo
# 4.jpeg
# Bless - Criollo
# 1.jpeg
# Bless - Criollo
# 2.jpeg
# Bless - Criollo
# 3.jpeg
# Bless - Criollo
# 4.jpeg
# Bless - Criollo
# 5.jpeg
# Alfonso - Criollo
# 1.jpeg
# Alfonso - Criollo
# 2.jpeg
# Alfonso - Criollo
# 3.jpeg
# Alfonso - Criollo
# 4.jpeg
# Alfonso - Criollo
# 5.jpeg
# Alfonso - Criollo
# 6.jpeg
# Alfonso - Criollo
# 7.jpeg
# Alfonso - Criollo
# 8.jpeg
# Alfonso - Criollo
# 9.jpeg
# Tom2- Criollo
# 1.jpeg
# Tom2- Criollo
# 2.jpeg
# Tom2- Criollo
# 3.jpeg
# Tom2- Criollo
# 4.jpeg
# Tom2- Criollo
# 5.jpeg
# Tom2- Criollo
# 6.jpeg
# Chacho - Criollo
# 1.jpeg
# Chacho - Criollo
# 2.jpeg
# Chacho - Criollo
# 3.jpeg
# Chacho - Criollo
# 4.jpeg
# Cheetara - Calico
# 1.jpeg
# Cheetara - Calico
# 2.jpeg
# Cheetara - Calico
# 3.jpeg
# Cheetara - Calico
# 4.jpeg
# Cheetara - Calico
# 5.jpeg
# Cheetara - Calico
# 6.jpeg
# Cheetara - Calico
# 7.jpeg
# Cheetara - Calico
# 8.jpeg
# Niño - Criollo
# 1.jpeg
# Niño - Criollo
# 2.jpeg
# Niño - Criollo
# 3.jpeg
# Niño - Criollo
# 4.jpeg
# Niño - Criollo
# 5.jpeg
# Niño - Criollo
# 6.jpeg
# Niño - Criollo
# 7.jpeg
# Minina - Criollo
# 1.jpeg
# Minina - Criollo
# 2.jpeg
# Minina - Criollo
# 3.jpeg
# Minina - Criollo
# 4.jpeg
# Minina - Criollo
# 5.jpeg
# Minina - Criollo
# 6.jpeg
# Minina - Criollo
# 7.jpeg
# Minina - Criollo
# 8.jpeg
# Jaspe - Americano
# 1.jpeg
# Jaspe - Americano
# 2.jpeg
# Jaspe - Americano
# 3.jpeg
# Niño - Persa
# 1.jpeg
# Niño - Persa
# 2.jpeg
# Niño - Persa
# 3.jpeg
# Lukitas - Europeo
# 1.jpeg
# Lukitas - Europeo
# 2.jpeg
# Lukitas - Europeo
# 3.jpeg
# Lukitas - Europeo
# 4.jpeg
# Lukitas - Europeo
# 5.jpeg
# Lukitas - Europeo
# 6.jpeg
# Simba - Criollo
# 1.jpeg
# Simba - Criollo
# 2.jpeg
# Simba - Criollo
# 3.jpeg
# Simba - Criollo
# 4.jpeg
# Simba - Criollo
# 5.jpeg
# Simba - Criollo
# 6.jpeg
# Ronny - Criollo
# 1.jpeg
# Ronny - Criollo
# 2.jpeg
# Ronny - Criollo
# 3.jpeg
# Ronny - Criollo
# 4.jpeg
# Uma - Criollo
# 1.jpeg
# Uma - Criollo
# 2.jpeg
# Uma - Criollo
# 3.jpeg
# Uma - Criollo
# 4.jpeg
# Ody - Persa
# 1.jpeg
# Ody - Persa
# 2.jpeg
# Ody - Persa
# 3.jpeg
# Ody - Persa
# 4.jpeg
# Ody - Persa
# 5.jpeg
# Brisa - Persa
# 1.jpeg
# Brisa - Persa
# 2.jpeg
# Brisa - Persa
# 3.jpeg
# Reichel - Persa
# 1.jpeg
# Reichel - Persa
# 2.jpeg
# Reichel - Persa
# 3.jpeg
# Reichel - Persa
# 4.jpeg
# Reichel - Persa
# 5.jpeg
# Reichel - Persa
# 6.jpeg
# Casparito - Persa
# 1.jpeg
# Casparito - Persa
# 2.jpeg
# Casparito - Persa
# 3.jpeg
# Casparito - Persa
# 4.jpeg
# Casparito - Persa
# 5.jpeg
# Kitty - Criollo
# 1.jpeg
# Kitty - Criollo
# 2.jpeg
# Kitty - Criollo
# 3.jpeg
# Milo - Criollo
# 1.jpeg
# Milo - Criollo
# 2.jpeg
# Milo - Criollo
# 3.jpeg
# Maggie - Siames
# 1.jpeg
# Maggie - Siames
# 2.jpeg
# Maggie - Siames
# 3.jpeg
# Maggie - Siames
# 4.jpeg
# Alpin - Criollo
# 1.jpeg
# Alpin - Criollo
# 2.jpeg
# Alpin - Criollo
# 3.jpeg
# Alpin - Criollo
# 4.jpeg
# Copito - Criollo
# 1.jpeg
# Copito - Criollo
# 2.jpeg
# Copito - Criollo
# 3.jpeg
# Copito - Criollo
# 4.jpeg
# Copito - Criollo
# 5.jpeg
# Copito - Criollo
# 6.jpeg
# Nala - Criollo (1)
# 1 (1).jpeg
# Nala - Criollo (1)
# 2 (1).jpeg
# Nala - Criollo (1)
# 3 (1).jpeg
# Nala - Criollo (1)
# 4 (1).jpeg
# Chispita - Calico
# WhatsApp Image 2020-06-28 at 12.45.24 PM.jpeg
# Chispita - Calico
# 2.jpeg
# Chispita - Calico
# 3.jpeg
# Chispita - Calico
# 4.jpeg
# Chispita - Calico
# 5.jpeg
# Chispita - Calico
# 6.jpeg
# Chispita - Calico
# 7.jpeg
# Chispita - Calico
# 8.jpeg
# Chispita - Calico
# 9.jpeg
# TERMINO !!
# Cantidad de imagenes  277
