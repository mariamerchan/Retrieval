# %% [markdown]
# #**1. Instalación de Pyterrier**
#
# [Repositorio de PyTerrier](https://github.com/terrier-org/pyterrier/blob/master/examples/notebooks/retrieval_and_evaluation.ipynb)

# %%
pip install python-terrier

# %% [markdown]
# #**2. Importamos Pyterrier y lo inicializamos**

# %%
import pyterrier as pt
if not pt.started():
  pt.init()

# %% [markdown]
# #**3. Cargamos el archivo de características Ejemplo**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/0_Desarrollo_Tesis/
# Out:
# /content/gdrive/.shortcut-targets-by-id/13aHaot6tbm7SROiS_JzQgfDtjZ_DM4PH/0_Desarrollo_Tesis

# %%
# !ls /content/gdrive/My\ Drive/0_Desarrollo_Tesis/5.Resultados_Histogramas/*

# %% [markdown]
# https://colab.research.google.com/github/terrier-org/pyterrier/blob/master/examples/notebooks/indexing.ipynb#scrollTo=JWLqWXBHeBRc

# %%
# !pip install python-terrier
#!pip install --upgrade git+https://github.com/terrier-org/pyterrier.git#egg=python-terrier

# %%
import pyterrier as pt
if not pt.started():
  pt.init()

# %%
import pandas as pd
# !rm -rf ./pd_index
pd_indexer = pt.DFIndexer("./pd_index")

# %%
import pandas as pd

lab_dataset = pd.read_csv("5.Resultados_Histogramas/Eigen_Perros/histograma_ruta_eigen.csv",header=None ,dtype=str)
lab_dataset_original = pd.read_csv("5.Resultados_Histogramas/Eigen_Perros/histograma_ruta_redimensionada.csv",header=None ,dtype=str)
lectura_histograma_dataset = pd.read_csv("5.Resultados_Histogramas/Eigen_Perros/histograma_caracteristicas.csv",header=None ,dtype=str)

df = pd.concat([lab_dataset,lab_dataset_original,lectura_histograma_dataset],axis=1)
df.to_csv("caracteristicas_globales_dataset.csv",index=None, header=None)
df

#list(df.columns)
#print(type(df))

#print(pd_indexer)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-50-327f5b5a1afa>", line 11, in <module>
#     pyterrier.io.find_files( dir )
# NameError: name 'pyterrier' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
# define an example dataframe of documents
import pandas as pd
df = pd.DataFrame({
    'docno':
    ['1', '2', '3'],
    'url':
    ['url1', 'url2', 'url3'],
    'text':
    ['He ran out of money, so he had to stop playing',
    'The waves were crashing on the shore; it was a',
    'The body may perhaps compensates for the loss']
})

# index the text, record the docnos as metadata
pd_indexer = pt.DFIndexer("./pd_index")
indexref = pd_indexer.index(df["text"], df["docno"])

# %%
https://pyterrier.readthedocs.io/en/latest/new.html#pyterrier.new.empty_Q


https://pyterrier.readthedocs.io/en/latest/new.html

https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

https://colab.research.google.com/github/terrier-org/pyterrier/blob/master/examples/notebooks/indexing.ipynb#scrollTo=vw-4NIjlUY16

https://pyterrier.readthedocs.io/en/stable/text.html#pt-text

# %%
import pandas as pd
# !rm -rf ./pd_index
pd_indexer = pt.DFIndexer("./pd_index")

df = pd.DataFrame({ 
'docno':
['1', '2', '3'],
'url': 
['url1', 'url2', 'url3'],
'text': 
['He ran out of money, so he had to stop playing',
'The waves were crashing on the shore; it was a',
'The body may perhaps compensates for the loss']
})

# no metadata
# pd_indexer.index(df["text"])

# Add metadata fields as Pandas.Series objects, with the name of the Series object becoming the name of the meta field.
indexref2 = pd_indexer.index(df["text"], df["docno"])
# pd_indexer.index(df["text"], df["docno"], df["url"])

# Add metadata fields as lists to a keyword arguement
# pd_indexer.index(df["text"], docno=["1","2","3"], url=["url1", "url2", "url3"])

# Add the metadata fields with a dictionary
# meta_fields={"docno":["1","2","3"],"url":["url1", "url2", "url3"]}
# pd_indexer.index(df["text"], **meta_fields)

# Add the entire dataframe as metadata
# pd_indexer.index(df["text"], df)

# %%
df = pd.DataFrame(
    [
        ["q1", "chemical reactions", "d1", "professor protor poured the chemicals"],
        ["q1", "chemical reactions", "d2", "chemical brothers turned up the beats"],
    ], columns=["qid", "query", "docno", "text"])
textscorerTf = pt.text.scorer(body_attr="text", wmodel="Tf")
rtr = textscorerTf.transform(df)
