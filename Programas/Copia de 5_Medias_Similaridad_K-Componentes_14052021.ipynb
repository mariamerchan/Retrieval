# %% [markdown]
# *** MEDIDAS DE SIMILARIDAD ***

# %% [markdown]
# Datos del Drive.
# 1. Conexión y permisos con el drive personal

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 2. Ubicación de las carpetas a utilizar

# %%
#%cd /content/gdrive/My Drive/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento/
# %cd /content/gdrive/My Drive/0_Desarrollo_Tesis/
# Out:
# /content/gdrive/.shortcut-targets-by-id/13aHaot6tbm7SROiS_JzQgfDtjZ_DM4PH/0_Desarrollo_Tesis

# %% [markdown]
# 3. Listar la lista del contenido de la ruta

# %%
# !ls /content/gdrive/My\ Drive/0_Desarrollo_Tesis/*

# %% [markdown]
# *** FUNCION DISTANCIA EUCLIDIANA***

# %%
import math
import numpy as np
#imagen_entrada, imagen_dataset
def distancia_euclidiana(x,y):
  suma=0
  #print('HOLA')
  #for j in range(1,256):
  for j in range(1,256):
    #print(int(x[0:257][(j)]))
    numx=(int(x[0:257][j]))
    #print(numx)
    numy=(int(y[0:257][j]))

    elevado=pow(numx-numy,2)
    suma=elevado+suma
    #suma=0
  return math.sqrt(suma)
  #return suma

# %% [markdown]
# *** FUNCION Distancia Manhattan ***

# %%
import math
import numpy as np
#imagen_entrada, imagen_dataset
def distancia_manhattan(x,y):
  suma=0
  print(range(256))
  for j in range(256):
    
    #numx=(int(x[0:255][j]))
    #numy=(int(y[0:255][j]))
    #valor_absoluto=abs(numx-numy)
    #suma=suma+valor_absoluto
    suma=0
  return suma

# %% [markdown]
# *** Lectura de Caracteristicas ***

# %%
import numpy as np
import pandas as pd

def funcion_lectura_carpetas(ARRAY_IMAGEN,ARRAY_DATASET, MEDIDA): #, MEDIDA PENDIENTE

  #[0]'histograma_ruta_redimensionada.csv'
  #[1]'histograma_caracteristicas.csv'
  #[2]'histograma_ruta_eigen.csv'

  
  if(os.path.isfile(ARRAY_DATASET[0]) and os.path.isfile(ARRAY_DATASET[1]) and os.path.isfile(ARRAY_DATASET[0])
     and os.path.isfile(ARRAY_IMAGEN[0]) and os.path.isfile(ARRAY_IMAGEN[1]) and os.path.isfile(ARRAY_IMAGEN[2])):
    
    #Imagen de Datasets
    rutas_dataset_original = pd.read_csv(ARRAY_DATASET[0],header=None ,dtype=str)
    lectura_histograma_dataset = pd.read_csv(ARRAY_DATASET[1], header= None)
    rutas_dataset = pd.read_csv(ARRAY_DATASET[2],header=None ,dtype=str)
    
    
    #Imagen de test
    rutas_test_original = pd.read_csv(ARRAY_IMAGEN[0],header=None ,dtype=str)
    lectura_histograma_test = pd.read_csv(ARRAY_IMAGEN[1], header= None)
    rutas_test = pd.read_csv(ARRAY_IMAGEN[2],header=None ,dtype=str)
    
    '''
    print('//////////////////////')
    print('*rutas_dataset*')
    print(len(rutas_dataset))
    print('*rutas_test*')
    print(len(rutas_test))
    print('//////////////////////')
    '''

    if MEDIDA==1:
      print('1. distancia_euclidiana')
      lectura_histograma_test_uno=lectura_histograma_test.drop(lectura_histograma_test.columns[[0]], axis= 1)
      lectura_histograma_dataset_uno=lectura_histograma_dataset.drop(lectura_histograma_dataset.columns[[0]], axis= 1)
      
      for i in range(len(rutas_test)):
        dataset_imagen_test=lectura_histograma_test_uno[0:257][(i):(i+1)]
        dataset_ruta_test=lectura_histograma_test[0][i]
        
        KA=dataset_ruta_test.split(sep='/')
        #CREACION DE ARCHIVOS CSV CON LAS CARACTERISTICAS
        ruta_almacenamiento="7.Medidas_Similaridad/"+ARRAY_IMAGEN[3] +"_"+ ARRAY_DATASET[3]
        os.makedirs(ruta_almacenamiento, exist_ok=True)
        archivo=KA[3]+"__distancia_euclidiana.csv"
        ruta_almacenamiento=ruta_almacenamiento+"/"+archivo
        archivo_euclidiana= open(ruta_almacenamiento, "w+") 

        archivo_euclidiana.write("# Ruta Query")
        archivo_euclidiana.write(",")
        archivo_euclidiana.write("# Sujetos Query")
        archivo_euclidiana.write(",")
        archivo_euclidiana.write("# Ruta Dataset")
        archivo_euclidiana.write(",")
        archivo_euclidiana.write("# Sujetos Dataset")
        archivo_euclidiana.write(",")
        archivo_euclidiana.write("# Valor Distancia Euclidiana")
        archivo_euclidiana.write("\n")
        

        for j in range(len(rutas_dataset)):
          dataset_imagen_dataset=lectura_histograma_dataset_uno[0:257][(j):(j+1)]
          dataset_ruta_dataset=lectura_histograma_dataset[0][j]
          KB=dataset_ruta_dataset.split(sep='/')
          #print(dataset_imagen_test)
          #print(dataset_imagen_dataset)
          #Resultados de la distancia euclidiana
          print('--------------------')
          print(str(j))
          print('[0:257][('+str(j)+'):('+str(j+1)+'))')
          resultado_euclidiana=distancia_euclidiana(dataset_imagen_test,dataset_imagen_dataset)
          print(resultado_euclidiana)
          print('--------------------')
          
          #print(str(resultado_euclidiana))
          
          archivo_euclidiana.write(dataset_ruta_test)
          archivo_euclidiana.write(",")
          archivo_euclidiana.write(str(KA[3]))
          archivo_euclidiana.write(",")
          archivo_euclidiana.write(dataset_ruta_dataset)
          archivo_euclidiana.write(",")
          archivo_euclidiana.write(str(KB[3]))
          archivo_euclidiana.write(",")
          archivo_euclidiana.write(str(10))
          archivo_euclidiana.write("\n")




   


  '''
  #print(lectura_histograma[0:255][0:1]) #[columna][fila]
  entrada_imagen=lectura_histograma[0:255][0:1]

  if MEDIDA==1:
    print('distancia_euclidiana')
    resultado=[]
    #print(len(lab_dataset))
    
    for i in range(len(lab_dataset)):
      dataset_imagen=lectura_histograma_dataset[0:255][(i):(i+1)]
      #Resultados de la distancia euclidiana
      resultado.append(distancia_euclidiana(entrada_imagen,dataset_imagen))
    
    
   
  
  elif MEDIDA==2:
    print('distancia_manhattan')
    resultado=[]
    for i in range(len(lab_dataset)):
      dataset_imagen=lectura_histograma_dataset[0:255][(i):(i+1)]
      #Resultados de la distancia_manhattan
      resultado.append(distancia_manhattan(entrada_imagen,dataset_imagen))

  else:
    print('Ninguna medida')

  '''

# %% [markdown]
# *** IMAGEN RESULTADO ***

# %%
#imagen resultado que tiene mas similitud con la imagen de entrada.
import cv2
import numpy as np
from matplotlib import pyplot as plt
def imagen_imprime(imagen):
  img = cv2.imread(imagen)
  img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(img_cvt)
  plt.show()

# %% [markdown]
# *** Preguntas de flujo ***

# %%
# Importar Librerias

import dlib, cv2, os
from imutils import face_utils
import numpy as np
import matplotlib.pyplot as plt
import os
from skimage import io, color
import cv2 as cv

# %%
def menu_tesis():
  print("-----------        Tesis U Catolica      -----------")
  print("----------- ** Medidas de similaridad ** -----------")
  print("----- Seleccione la tecnica por la que desea implementar -----")
  print("1. Eigen - (Gatos - GatosQUERY)")
  print("2. Eigen - (Gatos - Buscar Gato)")
  print("3. Eigen - (Perros - PerrosQUERY)")
  print("4. Eigen - (Perros - Buscar Perro)")
  
  print("-----------------------------------")

def menu_opcion():
  print("----------- Medidas de similaridad -----------")
  print("1. Distancia Euclidiana")
  print("2. Distancia Manhattan")
  print("-----------------------------------")

def seleccion_menu():
  menu_tesis()
  mopcion = int(input("Seleccione una opcion: "))
  caso_menu(mopcion)

def seleccion_opcion(mopcion):
  menu_opcion()
  opcion = int(input("Seleccione una opcion: "))
  #print(mopcion)
  #print(opcion)
  caso_opcion(mopcion,opcion)

# %%
def recorrer_kcomponentes(DATOS_UNO,DATOS_DOS, MEDIDA):
    print('*******************')
    print('DATOS_UNO : '+DATOS_UNO)
    print('DATOS_DOS : '+DATOS_DOS)
    print('MEDIDA : '+ str(MEDIDA))
    print('*******************')

    print('********* DATOS_UNO **********')
    #*******************************
    # DATASET ENTRENAMIENTO GATOS O PERROS
    #*******************************
    for kcom in os.listdir(DATOS_DOS): 
      print("kcom "+kcom)
      archivo1=DATOS_DOS + '/' + kcom+ '/' +'histograma_ruta_redimensionada.csv'
      archivo2=DATOS_DOS + '/' + kcom+ '/' +'histograma_caracteristicas.csv'
      archivo3=DATOS_DOS + '/' + kcom+ '/' +'histograma_ruta_eigen.csv'
      ARRAY_DATASET=[archivo1, archivo2, archivo3, kcom]
      

      #*******************************
      # DATASET PRUEBA GATOS O PERROS
      #*******************************
      for k2com in os.listdir(DATOS_UNO):
        
        if(kcom=='K_1' and k2com=='K_1' or  kcom=='K_1' and k2com=='K_2'): #or  kcom=='K_1' and k2com=='K_2'
          print("  ** k2com "+k2com)
          archivo_1=DATOS_UNO + '/' + k2com+ '/' +'histograma_ruta_redimensionada.csv'
          archivo_2=DATOS_UNO + '/' + k2com+ '/' +'histograma_caracteristicas.csv'
          archivo_3=DATOS_UNO + '/' + k2com+ '/' +'histograma_ruta_eigen.csv'
          ARRAY_DATASET2=[archivo_1, archivo_2, archivo_3, k2com]
          funcion_lectura_carpetas(ARRAY_DATASET,ARRAY_DATASET2, MEDIDA)
      
      '''
      for archivo in os.listdir(DATOS_UNO + '/' + kcom):
        #print('archivo: '+ archivo)
        ARRAY_DATASET.append(archivo)
      '''
      #print(ARRAY_DATASET)

    '''
    print('********* DATOS_DOS **********')
    for k2com in os.listdir(DATOS_DOS):
      #print('K : '+ k2com)
      ARRAY_DATASET2=[]
      for archivo2 in os.listdir(DATOS_DOS + '/' + k2com):
        #print('sujeto: '+ archivo)
        ARRAY_DATASET2.append(archivo2)
      print(ARRAY_DATASET2)

    MEDIDA=opcion
    #funcion_prueba(ARRAY_DATASET,ARRAY_IMAGEN, MEDIDA)
    '''

# %%
class caso_opcion:
  def __init__(self, mopcion,opcion):

    #*****************
    #      EIGEN
    #*****************

    if mopcion== 1 and opcion == 1: 
      print('1. Eigen - (Gatos - GatosQUERY), 1. Distancia Euclidiana')
      DATOS_UNO='5.Resultados_Histogramas/Eigen_Gatos'
      DATOS_DOS='5.Resultados_Histogramas/Eigen_Gatos_QUERY'
      MEDIDA=opcion
      recorrer_kcomponentes(DATOS_UNO,DATOS_DOS, MEDIDA)
      
    else:
      print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
      print('Error: La opción ingresada de BUSQUEDA no esta dentro de las opciones, por favor vuelva a ingresar la opción')
      print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
      print('')
      print('')
      print('')
      seleccion_opcion()

# %%
def caso_menu(mopcion):
  if mopcion == 1:
    print('Eigen - (Gatos - GatosQUERY)')
    seleccion_opcion(mopcion)
  else:
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    print('Error: La opción ingresada no esta dentro de las opciones, por favor vuelva a ingresar la opción')
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    print('')
    print('')
    
    seleccion_menu()

seleccion_menu()
# Out:
# -----------        Tesis U Catolica      -----------
# ----------- ** Medidas de similaridad ** -----------
# ----- Seleccione la tecnica por la que desea implementar -----
# 1. Eigen - (Gatos - GatosQUERY)
# 2. Eigen - (Gatos - Buscar Gato)
# 3. Eigen - (Perros - PerrosQUERY)
# 4. Eigen - (Perros - Buscar Perro)
# -----------------------------------
# Seleccione una opcion: 1
# Eigen - (Gatos - GatosQUERY)
# ----------- Medidas de similaridad -----------
# 1. Distancia Euclidiana
# 2. Distancia Manhattan
# -----------------------------------
# Seleccione una opcion: 1
# 1. Eigen - (Gatos - GatosQUERY), 1. Distancia Euclidiana
# *******************
# DATOS_UNO : 5.Resultados_Histogramas/Eigen_Gatos
# DATOS_DOS : 5.Resultados_Histogramas/Eigen_Gatos_QUERY
# MEDIDA : 1
# *******************
# ********* DATOS_UNO **********
# kcom K_1
#   ** k2com K_1
# 1. distancia_euclidiana
# --------------------
# 0
# [0:257][(0):(1))
# 8376.026563950236
# --------------------
# --------------------
# 1
# [0:257][(1):(2))
# 8354.563004729811
# --------------------
# --------------------
# 2
# [0:257][(2):(3))
# 7793.982999724852
# --------------------
# --------------------
# 3
# [0:257][(3):(4))
# 6253.61167646345
# --------------------
# --------------------
# 4
# [0:257][(4):(5))
# 3799.4725949794665
# --------------------
# --------------------
# 5
# [0:257][(5):(6))
# 3052.931705754323
# --------------------
# --------------------
# 6
# [0:257][(6):(7))
# 8739.915674650414
# --------------------
# --------------------
# 7
# [0:257][(7):(8))
# 8409.504206551062
# --------------------
# --------------------
# 8
# [0:257][(8):(9))
# 8889.62293913527
# --------------------
# --------------------
# 9
# [0:257][(9):(10))
# 5474.004567042304
# --------------------
# --------------------
# 10
# [0:257][(10):(11))
# 8246.965320649771
# --------------------
# --------------------
# 11
# [0:257][(11):(12))
# 8329.799997598982
# --------------------
# --------------------
# 12
# [0:257][(12):(13))
# 8157.000735564513
# --------------------
# --------------------
# 13
# [0:257][(13):(14))
# 8761.722205137527
# --------------------
# --------------------
# 14
# [0:257][(14):(15))
# 7864.053471333978
# --------------------
# --------------------
# 15
# [0:257][(15):(16))
# 4697.025122351381
# --------------------
# --------------------
# 16
# [0:257][(16):(17))
# 6672.915404828687
# --------------------
# --------------------
# 17
# [0:257][(17):(18))
# 5344.404550555656
# --------------------
# --------------------
# 18
# [0:257][(18):(19))
# 6269.4694352871675
# --------------------
# --------------------
# 19
# [0:257][(19):(20))
# 1466.003069573867
# --------------------
# --------------------
# 20
# [0:257][(20):(21))
# 6130.5948324775145
# --------------------
# --------------------
# 21
# [0:257][(21):(22))
# 7107.2795780101405
# --------------------
# --------------------
# 22
# [0:257][(22):(23))
# 2646.1328386912096
# --------------------
# --------------------
# 23
# [0:257][(23):(24))
# 7077.976476366674
# --------------------
# --------------------
# 24
# [0:257][(24):(25))
# 6893.583175678668
# --------------------
# --------------------
# 25
# [0:257][(25):(26))
# 7073.186198595368
# --------------------
# --------------------
# 26
# [0:257][(26):(27))
# 2904.939069929006
# --------------------
# --------------------
# 27
# [0:257][(27):(28))
# 7121.127649466761
# --------------------
# --------------------
# 28
# [0:257][(28):(29))
# 5338.798553981973
# --------------------
# --------------------
# 29
# [0:257][(29):(30))
# 8578.453065675652
# --------------------
# --------------------
# 30
# [0:257][(30):(31))
# 1602.6687118678021
# --------------------
# --------------------
# 31
# [0:257][(31):(32))
# 8250.217875910914
# --------------------
# --------------------
# 32
# [0:257][(32):(33))
# 2887.386707734175
# --------------------
# --------------------
# 33
# [0:257][(33):(34))
# 8828.32787112033
# --------------------
# --------------------
# 34
# [0:257][(34):(35))
# 6442.938848072361
# --------------------
# --------------------
# 35
# [0:257][(35):(36))
# 6493.4191301655555
# --------------------
# --------------------
# 36
# [0:257][(36):(37))
# 4641.920400006877
# --------------------
# --------------------
# 37
# [0:257][(37):(38))
# 6560.648824620931
# --------------------
# --------------------
# 38
# [0:257][(38):(39))
# 6628.748976994076
# --------------------
# --------------------
# 39
# [0:257][(39):(40))
# 8622.746082310437
# --------------------
# --------------------
# 40
# [0:257][(40):(41))
# 3304.4601677127234
# --------------------
# --------------------
# 41
# [0:257][(41):(42))
# 8751.496900530788
# --------------------
# --------------------
# 42
# [0:257][(42):(43))
# 5586.798904560643
# --------------------
# --------------------
# 43
# [0:257][(43):(44))
# 5553.074013553214
# --------------------
# --------------------
# 44
# [0:257][(44):(45))
# 3590.38103827435
# --------------------
# --------------------
# 45
# [0:257][(45):(46))
# 7998.289254584382
# --------------------
# --------------------
# 46
# [0:257][(46):(47))
# 6457.29060829695
# --------------------
# --------------------
# 47
# [0:257][(47):(48))
# 6068.516045953904
# --------------------
# --------------------
# 48
# [0:257][(48):(49))
# 7969.865933627742
# --------------------
# --------------------
# 49
# [0:257][(49):(50))
# 8839.283964213391
# --------------------
# --------------------
# 50
# [0:257][(50):(51))
# 7182.737918092237
# --------------------
# --------------------
# 51
# [0:257][(51):(52))
# 7008.920102269679
# --------------------
# --------------------
# 52
# [0:257][(52):(53))
# 7477.3487948603815
# --------------------
# --------------------
# 53
# [0:257][(53):(54))
# 5714.184281242599
# --------------------
# --------------------
# 54
# [0:257][(54):(55))
# 8536.695496502145
# --------------------
# --------------------
# 55
# [0:257][(55):(56))
# 5184.940886837573
# --------------------
# --------------------
# 56
# [0:257][(56):(57))
# 1833.8923087248063
# --------------------
# --------------------
# 57
# [0:257][(57):(58))
# 6068.80243540684
# --------------------
# --------------------
# 58
# [0:257][(58):(59))
# 8543.378781255107
# --------------------
# --------------------
# 59
# [0:257][(59):(60))
# 8421.746077862952
# --------------------
# --------------------
# 60
# [0:257][(60):(61))
# 8814.036419257638
# --------------------
# --------------------
# 61
# [0:257][(61):(62))
# 5652.488832364023
# --------------------
# --------------------
# 62
# [0:257][(62):(63))
# 8637.08857196683
# --------------------
# --------------------
# 63
# [0:257][(63):(64))
# 6694.102254970416
# --------------------
# --------------------
# 64
# [0:257][(64):(65))
# 8054.040849163853
# --------------------
# --------------------
# 65
# [0:257][(65):(66))
# 7547.940513809048
# --------------------
# --------------------
# 66
# [0:257][(66):(67))
# 8285.498295214356
# --------------------
# --------------------
# 67
# [0:257][(67):(68))
# 8898.764015300103
# --------------------
# --------------------
# 68
# [0:257][(68):(69))
# 8797.597285622933
# --------------------
# --------------------
# 69
# [0:257][(69):(70))
# 4446.080970922594
# --------------------
# --------------------
# 70
# [0:257][(70):(71))
# 3597.8207292748757
# --------------------
# --------------------
# 71
# [0:257][(71):(72))
# 3359.3011177922112
# --------------------
# --------------------
# 72
# [0:257][(72):(73))
# 3460.2296166584088
# --------------------
# --------------------
# 73
# [0:257][(73):(74))
# 8276.59501244322
# --------------------
# --------------------
# 74
# [0:257][(74):(75))
# 8168.22196074519
# --------------------
# --------------------
# 75
# [0:257][(75):(76))
# 7082.323771192616
# --------------------
# --------------------
# 76
# [0:257][(76):(77))
# 8840.92506472032
# --------------------
# --------------------
# 77
# [0:257][(77):(78))
# 7820.224485268949
# --------------------
# --------------------
# 78
# [0:257][(78):(79))
# 8075.230523025333
# --------------------
# --------------------
# 79
# [0:257][(79):(80))
# 6922.210774022993
# --------------------
# --------------------
# 80
# [0:257][(80):(81))
# 7990.10707062177
# --------------------
# --------------------
# 81
# [0:257][(81):(82))
# 6303.133189136971
# --------------------
# --------------------
# 82
# [0:257][(82):(83))
# 7033.931333187722
# --------------------
# --------------------
# 83
# [0:257][(83):(84))
# 7034.185453910069
# --------------------
# --------------------
# 84
# [0:257][(84):(85))
# 7040.454317726946
# --------------------
# --------------------
# 85
# [0:257][(85):(86))
# 7103.614432104265
# --------------------
# --------------------
# 86
# [0:257][(86):(87))
# 6958.29857077145
# --------------------
# --------------------
# 87
# [0:257][(87):(88))
# 8278.143511681832
# --------------------
# --------------------
# 88
# [0:257][(88):(89))
# 1877.0620661022374
# --------------------
# --------------------
# 89
# [0:257][(89):(90))
# 8031.178742874547
# --------------------
# --------------------
# 90
# [0:257][(90):(91))
# 8558.068181546581
# --------------------
# --------------------
# 91
# [0:257][(91):(92))
# 8401.653765777306
# --------------------
# --------------------
# 92
# [0:257][(92):(93))
# 8286.635264086382
# --------------------
# --------------------
# 93
# [0:257][(93):(94))
# 4421.416967443808
# --------------------
# --------------------
# 94
# [0:257][(94):(95))
# 6921.114722355063
# --------------------
# --------------------
# 95
# [0:257][(95):(96))
# 8456.84042654229
# --------------------
# --------------------
# 96
# [0:257][(96):(97))
# 4304.396589534937
# --------------------
# --------------------
# 97
# [0:257][(97):(98))
# 5593.779580927371
# --------------------
# --------------------
# 98
# [0:257][(98):(99))
# 1667.9229598515635
# --------------------
# --------------------
# 99
# [0:257][(99):(100))
# 5910.303630102264
# --------------------
# --------------------
# 100
# [0:257][(100):(101))
# 8336.521036979395
# --------------------
# --------------------
# 101
# [0:257][(101):(102))
# 6035.128913287603
# --------------------
# --------------------
# 102
# [0:257][(102):(103))
# 8343.80836309176
# --------------------
# --------------------
# 103
# [0:257][(103):(104))
# 7062.370565185602
# --------------------
# --------------------
# 104
# [0:257][(104):(105))
# 7088.763361828352
# --------------------
# --------------------
# 105
# [0:257][(105):(106))
# 1814.3051011337648
# --------------------
# --------------------
# 106
# [0:257][(106):(107))
# 3062.578325528998
# --------------------
# --------------------
# 107
# [0:257][(107):(108))
# 6975.01555553821
# --------------------
# --------------------
# 108
# [0:257][(108):(109))
# 7018.433015994382
# --------------------
# --------------------
# 109
# [0:257][(109):(110))
# 7997.335806379522
# --------------------
# --------------------
# 110
# [0:257][(110):(111))
# 5385.4147472594905
# --------------------
# --------------------
# 111
# [0:257][(111):(112))
# 8861.231460694387
# --------------------
# --------------------
# 112
# [0:257][(112):(113))
# 4695.786089676573
# --------------------
# --------------------
# 113
# [0:257][(113):(114))
# 8892.604511615256
# --------------------
# --------------------
# 114
# [0:257][(114):(115))
# 8556.057912379976
# --------------------
# --------------------
# 115
# [0:257][(115):(116))
# 3492.9886916507476
# --------------------
# --------------------
# 116
# [0:257][(116):(117))
# 6344.423614482249
# --------------------
# --------------------
# 117
# [0:257][(117):(118))
# 5158.084722064964
# --------------------
# --------------------
# 118
# [0:257][(118):(119))
# 3824.700903338717
# --------------------
# --------------------
# 119
# [0:257][(119):(120))
# 2354.2478629065376
# --------------------
# --------------------
# 120
# [0:257][(120):(121))
# 8432.462155266396
# --------------------
# --------------------
# 121
# [0:257][(121):(122))
# 2492.41027922772
# --------------------
# --------------------
# 122
# [0:257][(122):(123))
# 7121.65963803382
# --------------------
# --------------------
# 123
# [0:257][(123):(124))
# 5394.683586643428
# --------------------
# --------------------
# 124
# [0:257][(124):(125))
# 1406.9310573016717
# --------------------
# --------------------
# 125
# [0:257][(125):(126))
# 7105.105066077489
# --------------------
# --------------------
# 126
# [0:257][(126):(127))
# 5913.620549206721
# --------------------
# --------------------
# 127
# [0:257][(127):(128))
# 1453.771990375382
# --------------------
# --------------------
# 128
# [0:257][(128):(129))
# 1078.9277084216533
# --------------------
# --------------------
# 129
# [0:257][(129):(130))
# 7009.856845899209
# --------------------
# --------------------
# 130
# [0:257][(130):(131))
# 5158.144627673792
# --------------------
# --------------------
# 131
# [0:257][(131):(132))
# 1944.0239196059292
# --------------------
# --------------------
# 132
# [0:257][(132):(133))
# 6976.228923996116
# --------------------
# --------------------
# 133
# [0:257][(133):(134))
# 7097.4183334505515
# --------------------
# --------------------
# 134
# [0:257][(134):(135))
# 7059.109292254937
# --------------------
# --------------------
# 135
# [0:257][(135):(136))
# 6925.853665794564
# --------------------
# --------------------
# 136
# [0:257][(136):(137))
# 7066.41564019553
# --------------------
# --------------------
# 137
# [0:257][(137):(138))
# 8768.637579464668
# --------------------
# --------------------
# 138
# [0:257][(138):(139))
# 8440.613129388172
# --------------------
# --------------------
# 139
# [0:257][(139):(140))
# 5171.8148652093105
# --------------------
# --------------------
# 140
# [0:257][(140):(141))
# 2006.9583951841155
# --------------------
# --------------------
# 141
# [0:257][(141):(142))
# 8893.630080006702
# --------------------
# --------------------
# 142
# [0:257][(142):(143))
# 8724.781945699273
# --------------------
# --------------------
# 143
# [0:257][(143):(144))
# 1603.0938837136146
# --------------------
# --------------------
# 144
# [0:257][(144):(145))
# 1171.8643266180604
# --------------------
# --------------------
# 145
# [0:257][(145):(146))
# 2042.0426048444729
# --------------------
# --------------------
# 146
# [0:257][(146):(147))
# 7105.162770830799
# --------------------
# --------------------
# 147
# [0:257][(147):(148))
# 1988.9906988218925
# --------------------
# --------------------
# 148
# [0:257][(148):(149))
# 7110.872168728672
# --------------------
# --------------------
# 149
# [0:257][(149):(150))
# 6063.518203155656
# --------------------
# --------------------
# 150
# [0:257][(150):(151))
# 6167.88472654929
# --------------------
# --------------------
# 151
# [0:257][(151):(152))
# 6880.984522581053
# --------------------
# --------------------
# 152
# [0:257][(152):(153))
# 1575.3304415264754
# --------------------
# --------------------
# 153
# [0:257][(153):(154))
# 8298.08092271942
# --------------------
# --------------------
# 154
# [0:257][(154):(155))
# 2537.9192264530407
# --------------------
# --------------------
# 155
# [0:257][(155):(156))
# 4459.559619514017
# --------------------
# --------------------
# 156
# [0:257][(156):(157))
# 8783.048844222603
# --------------------
# --------------------
# 157
# [0:257][(157):(158))
# 7099.122480983125
# --------------------
# --------------------
# 158
# [0:257][(158):(159))
# 7116.230392560376
# --------------------
# --------------------
# 159
# [0:257][(159):(160))
# 6951.6231198188525
# --------------------
# --------------------
# 160
# [0:257][(160):(161))
# 6999.514125994747
# --------------------
# --------------------
# 161
# [0:257][(161):(162))
# 7093.011772159975
# --------------------
# --------------------
# 162
# [0:257][(162):(163))
# 7133.451338587794
# --------------------
# --------------------
# 163
# [0:257][(163):(164))
# 7116.22175033915
# --------------------
# --------------------
# 164
# [0:257][(164):(165))
# 3727.693388678849
# --------------------
# --------------------
# 165
# [0:257][(165):(166))
# 4726.822188320606
# --------------------
# --------------------
# 166
# [0:257][(166):(167))
# 2244.3092478533345
# --------------------
# --------------------
# 167
# [0:257][(167):(168))
# 6248.8049257438015
# --------------------
# --------------------
# 168
# [0:257][(168):(169))
# 5998.845638954214
# --------------------
# --------------------
# 169
# [0:257][(169):(170))
# 6894.204522640737
# --------------------
# --------------------
# 170
# [0:257][(170):(171))
# 7036.205866800658
# --------------------
# --------------------
# 171
# [0:257][(171):(172))
# 4393.990669084312
# --------------------
# --------------------
# 172
# [0:257][(172):(173))
# 6215.609624163989
# --------------------
# --------------------
# 173
# [0:257][(173):(174))
# 1606.9660855164307
# --------------------
# --------------------
# 174
# [0:257][(174):(175))
# 7046.439597413718
# --------------------
# --------------------
# 175
# [0:257][(175):(176))
# 6336.940034433022
# --------------------
# --------------------
# 176
# [0:257][(176):(177))
# 7058.990012742616
# --------------------
# --------------------
# 177
# [0:257][(177):(178))
# 6928.648641690528
# --------------------
# --------------------
# 178
# [0:257][(178):(179))
# 6919.264773081024
# --------------------
# --------------------
# 179
# [0:257][(179):(180))
# 7010.901011995534
# --------------------
# --------------------
# 180
# [0:257][(180):(181))
# 7074.2513384809845
# --------------------
# --------------------
# 181
# [0:257][(181):(182))
# 7088.180655146989
# --------------------
# --------------------
# 182
# [0:257][(182):(183))
# 7017.634715486408
# --------------------
# --------------------
# 183
# [0:257][(183):(184))
# 6904.976538700186
# --------------------
# --------------------
# 184
# [0:257][(184):(185))
# 7027.297773682285
# --------------------
# --------------------
# 185
# [0:257][(185):(186))
# 7100.752917824982
# --------------------
# --------------------
# 186
# [0:257][(186):(187))
# 6844.764495583468
# --------------------
# --------------------
# 187
# [0:257][(187):(188))
# 7098.864204927433
# --------------------
# --------------------
# 188
# [0:257][(188):(189))
# 7118.848291683143
# --------------------
# --------------------
# 189
# [0:257][(189):(190))
# 6957.031191535654
# --------------------
# --------------------
# 190
# [0:257][(190):(191))
# 6387.048144487405
# --------------------
# --------------------
# 191
# [0:257][(191):(192))
# 7090.017207313393
# --------------------
# --------------------
# 192
# [0:257][(192):(193))
# 7102.226833888087
# --------------------
# --------------------
# 193
# [0:257][(193):(194))
# 7105.649161054886
# --------------------
# --------------------
# 194
# [0:257][(194):(195))
# 1056.3739868058092
# --------------------
# --------------------
# 195
# [0:257][(195):(196))
# 4244.72107446414
# --------------------
# --------------------
# 196
# [0:257][(196):(197))
# 6577.444868640101
# --------------------
# --------------------
# 197
# [0:257][(197):(198))
# 6894.430143238816
# --------------------
# --------------------
# 198
# [0:257][(198):(199))
# 7004.493414944438
# --------------------
# --------------------
# 199
# [0:257][(199):(200))
# 6260.505969967603
# --------------------
# --------------------
# 200
# [0:257][(200):(201))
# 6185.353506469942
# --------------------
# --------------------
# 201
# [0:257][(201):(202))
# 7115.312010024578
# --------------------
# --------------------
# 202
# [0:257][(202):(203))
# 7108.835277315125
# --------------------
# --------------------
# 203
# [0:257][(203):(204))
# 7122.2672654148555
# --------------------
# --------------------
# 204
# [0:257][(204):(205))
# 7091.12896512255
# --------------------
# --------------------
# 205
# [0:257][(205):(206))
# 6418.251007868109
# --------------------
# --------------------
# 206
# [0:257][(206):(207))
# 2244.851442746268
# --------------------
# --------------------
# 207
# [0:257][(207):(208))
# 7944.0940956159375
# --------------------
# --------------------
# 208
# [0:257][(208):(209))
# 8640.321116717827
# --------------------
# --------------------
# 209
# [0:257][(209):(210))
# 5734.203519234385
# --------------------
# --------------------
# 210
# [0:257][(210):(211))
# 6103.128460060463
# --------------------
# --------------------
# 211
# [0:257][(211):(212))
# 1183.6878811578667
# --------------------
# --------------------
# 212
# [0:257][(212):(213))
# 1281.755436891141
# --------------------
# --------------------
# 213
# [0:257][(213):(214))
# 8875.44517193363
# --------------------
# --------------------
# 214
# [0:257][(214):(215))
# 6968.165181739021
# --------------------
# --------------------
# 215
# [0:257][(215):(216))
# 7006.4438197990285
# --------------------
# --------------------
# 216
# [0:257][(216):(217))
# 7119.5470361533535
# --------------------
# --------------------
# 217
# [0:257][(217):(218))
# 7042.725324758875
# --------------------
# --------------------
# 218
# [0:257][(218):(219))
# 3578.0286471743066
# --------------------
# --------------------
# 219
# [0:257][(219):(220))
# 4627.651888377085
# --------------------
# --------------------
# 220
# [0:257][(220):(221))
# 8790.421946641696
# --------------------
# --------------------
# 221
# [0:257][(221):(222))
# 5157.321203880945
# --------------------
# --------------------
# 222
# [0:257][(222):(223))
# 5997.069951234519
# --------------------
# --------------------
# 223
# [0:257][(223):(224))
# 8808.807070199688
# --------------------
# --------------------
# 224
# [0:257][(224):(225))
# 8867.479630650414
# --------------------
# --------------------
# 225
# [0:257][(225):(226))
# 7726.258861829572
# --------------------
# --------------------
# 226
# [0:257][(226):(227))
# 8701.550034332964
# --------------------
# --------------------
# 227
# [0:257][(227):(228))
# 6051.666629945837
# --------------------
# --------------------
# 228
# [0:257][(228):(229))
# 7076.802031991569
# --------------------
# --------------------
# 229
# [0:257][(229):(230))
# 7083.743995938871
# --------------------
# --------------------
# 230
# [0:257][(230):(231))
# 7117.970216290596
# --------------------
# --------------------
# 231
# [0:257][(231):(232))
# 7099.460402030566
# --------------------
# --------------------
# 232
# [0:257][(232):(233))
# 7105.080295112786
# --------------------
# --------------------
# 233
# [0:257][(233):(234))
# 7002.096900214963
# --------------------
# --------------------
# 234
# [0:257][(234):(235))
# 7111.925618283701
# --------------------
# --------------------
# 235
# [0:257][(235):(236))
# 6929.712187385563
# --------------------
# --------------------
# 236
# [0:257][(236):(237))
# 6884.92955664762
# --------------------
# --------------------
# 237
# [0:257][(237):(238))
# 6934.3060215136165
# --------------------
# --------------------
# 238
# [0:257][(238):(239))
# 8881.459621030768
# --------------------
# --------------------
# 239
# [0:257][(239):(240))
# 4415.887906186025
# --------------------
# --------------------
# 240
# [0:257][(240):(241))
# 1591.9679645017986
# --------------------
# --------------------
# 241
# [0:257][(241):(242))
# 8015.658113966688
# --------------------
# --------------------
# 242
# [0:257][(242):(243))
# 8898.586123649082
# --------------------
# --------------------
# 243
# [0:257][(243):(244))
# 8891.113990946242
# --------------------
# --------------------
# 244
# [0:257][(244):(245))
# 1966.6972314009088
# --------------------
# --------------------
# 245
# [0:257][(245):(246))
# 3766.055363374256
# --------------------
# --------------------
# 246
# [0:257][(246):(247))
# 7066.834793597484
# --------------------
# --------------------
# 247
# [0:257][(247):(248))
# 7121.13972619552
# --------------------
# --------------------
# 248
# [0:257][(248):(249))
# 7116.125490742838
# --------------------
# --------------------
# 249
# [0:257][(249):(250))
# 4687.2484465835605
# --------------------
# --------------------
# 250
# [0:257][(250):(251))
# 1948.227399458287
# --------------------
# --------------------
# 251
# [0:257][(251):(252))
# 5407.910594675174
# --------------------
# --------------------
# 252
# [0:257][(252):(253))
# 5260.161309313622
# --------------------
# --------------------
# 253
# [0:257][(253):(254))
# 3920.977684200715
# --------------------
# --------------------
# 254
# [0:257][(254):(255))
# 7327.970114567881
# --------------------
# --------------------
# 255
# [0:257][(255):(256))
# 3636.287392382511
# --------------------
# --------------------
# 256
# [0:257][(256):(257))
# 7484.414138728562
# --------------------
# --------------------
# 257
# [0:257][(257):(258))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-e579403908cd> in <module>()
#      13     seleccion_menu()
#      14
# ---> 15 seleccion_menu()
#
# <ipython-input-9-81b023128a43> in seleccion_menu()
#      19   menu_tesis()
#      20   mopcion = int(input("Seleccione una opcion: "))
# ---> 21   caso_menu(mopcion)
#      22
#      23 def seleccion_opcion(mopcion):
#
# <ipython-input-30-e579403908cd> in caso_menu(mopcion)
#       3   if mopcion == 1:
#       4     print('Eigen - (Gatos - GatosQUERY)')
# ----> 5     seleccion_opcion(mopcion)
#       6   else:
#       7     print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
#
# <ipython-input-9-81b023128a43> in seleccion_opcion(mopcion)
#      26   #print(mopcion)
#      27   #print(opcion)
# ---> 28   caso_opcion(mopcion,opcion)
#
# <ipython-input-11-3f68472e0c2b> in __init__(self, mopcion, opcion)
#      12       DATOS_DOS='5.Resultados_Histogramas/Eigen_Gatos_QUERY'
#      13       MEDIDA=opcion
# ---> 14       recorrer_kcomponentes(DATOS_UNO,DATOS_DOS, MEDIDA)
#      15
#      16     else:
#
# <ipython-input-27-0cf1db661390> in recorrer_kcomponentes(DATOS_UNO, DATOS_DOS, MEDIDA)
#      29           archivo_3=DATOS_UNO + '/' + k2com+ '/' +'histograma_ruta_eigen.csv'
#      30           ARRAY_DATASET2=[archivo_1, archivo_2, archivo_3, k2com]
# ---> 31           funcion_lectura_carpetas(ARRAY_DATASET,ARRAY_DATASET2, MEDIDA)
#      32
#      33       '''
#
# <ipython-input-29-90a016b03009> in funcion_lectura_carpetas(ARRAY_IMAGEN, ARRAY_DATASET, MEDIDA)
#      71           print(str(j))
#      72           print('[0:257][('+str(j)+'):('+str(j+1)+'))')
# ---> 73           resultado_euclidiana=distancia_euclidiana(dataset_imagen_test,dataset_imagen_dataset)
#      74           print(resultado_euclidiana)
#      75           print('--------------------')
#
# <ipython-input-26-7746b5f05698> in distancia_euclidiana(x, y)
#      10     numx=(int(x[0:257][j]))
#      11     #print(numx)
# ---> 12     numy=(int(y[0:257][j]))
#      13
#      14     elevado=pow(numx-numy,2)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in wrapper(self)
#     127         if len(self) == 1:
#     128             return converter(self.iloc[0])
# --> 129         raise TypeError(f"cannot convert the series to {converter}")
#     130
#     131     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>
