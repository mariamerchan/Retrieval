# %% [markdown]
# *** MEDIDAS DE SIMILARIDAD ***

# %% [markdown]
# Datos del Drive.
# 1. Conexión y permisos con el drive personal

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# 2. Ubicación de las carpetas a utilizar

# %%
#%cd /content/gdrive/My Drive/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento/
# %cd /content/gdrive/My Drive/0_Desarrollo_Tesis/
# Out:
# /content/gdrive/My Drive/0_Desarrollo_Tesis

# %% [markdown]
# 3. Listar la lista del contenido de la ruta

# %%
# !ls '/content/gdrive/My Drive/0_Desarrollo_Tesis/7.Medidas_Similaridad/3. Eigen - (Perros - PerrosQUERY) Distancia_Manhattana/32_Duke_Pug__distancia_manhattan.csv'*

# !ls '/content/gdrive/My Drive/0_Desarrollo_Tesis/5.Resultados_Histogramas/LBPH_Perros/'*
# Out:
# histograma_caracteristicas.csv	histograma_ruta_redimensionada.csv
# histograma_ruta_LBPH.csv

# %% [markdown]
# *** Lectura de Caracteristicas ***

# %%
import numpy as np
import pandas as pd

ruta_caracteristicas='5.Resultados_Histogramas/LBPH_Perros/LBPH/histograma_caracteristicas.csv'
ruta_euclidiana='7.Medidas_Similaridad/3. Eigen - (Perros - PerrosQUERY) Distancia_Manhattana/K_1_K_2/32_Duke_Pug__distancia_manhattan.csv'


import pandas as pd

lectura_histograma = pd.read_csv(ruta_euclidiana, header= None)

df = pd.concat([lectura_histograma],axis=1)
df.to_csv("caracteristicas_globales.csv",index=None, header=None)
df
# Out:
#                                                      0  ...                             4
# 0                                         # Ruta Query  ...  # Valor Distancia Euclidiana
# 1    4.Resultados_ext_caracteristicas/Eigen_Perros_...  ...                         28575
# 2    4.Resultados_ext_caracteristicas/Eigen_Perros_...  ...                         35115
# 3    4.Resultados_ext_caracteristicas/Eigen_Perros_...  ...                         32020
# 4    4.Resultados_ext_caracteristicas/Eigen_Perros_...  ...                         31215
# ..                                                 ...  ...                           ...
# 541  4.Resultados_ext_caracteristicas/Eigen_Perros_...  ...                         10490
# 542  4.Resultados_ext_caracteristicas/Eigen_Perros_...  ...                         33298
# 543  4.Resultados_ext_caracteristicas/Eigen_Perros_...  ...                         61588
# ...
