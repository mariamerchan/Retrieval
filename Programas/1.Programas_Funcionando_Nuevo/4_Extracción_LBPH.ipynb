# %% [markdown]
# *** EXTRACCION DE CARACTETISTICAS LBPH ***

# %% [markdown]
# Datos del Drive.
# 1. Conexión y permisos con el drive personal

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# 2. Ubicación de las carpetas a utilizar

# %%
#%cd /content/gdrive/My Drive/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento/
# %cd /content/gdrive/My Drive/0_Desarrollo_Tesis/
# Out:
# /content/gdrive/My Drive/0_Desarrollo_Tesis

# %% [markdown]
# 3. Listar la lista del contenido de la ruta

# %%
# !ls /content/gdrive/My\ Drive/0_Desarrollo_Tesis/*

# %% [markdown]
# ***FUNCION HISTOGRAMA***

# %%
def histogram(imgGRAY):
    #histograma
    hist = cv.calcHist([imgGRAY],[0],None,[256],[0,256])
    # return the histogram
    return hist.flatten()

# %%
# CODIGO DE PRUEBAS

def funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo):
  print("path_EXTRACCION"+path_EXTRACCION)
  print("path_REDIMENSIONADO"+path_REDIMENSIONADO)
  print("anexo_archivo"+anexo_archivo)

# %% [markdown]
# *** LBPH ***

# %%
# Importar Librerias

import dlib, cv2, os
from imutils import face_utils
import numpy as np
import matplotlib.pyplot as plt
import os
from skimage import io, color
import cv2 as cv

# %%
def menu_tesis():
  print("----------- Tesis U Catolica -----------")
  print("----------- Seleccione la tecnica a implementar -----------")
  print("1. LPBH")
  print("-----------------------------------")

# %%
def menu_opcion():
  print("----------- Medidas de similaridad -----------")
  print("1. Perros")
  print("2. Buscar Perro")
  print("3. Gatos")
  print("4. Buscar Gato")
  print("5. Gatos QUERY")
  print("6. Perros QUERY")
  print("-----------------------------------")

# %%
def seleccion_menu():
  menu_tesis()
  mopcion = int(input("Seleccione una opcion: "))
  caso_menu(mopcion)

# %%
def seleccion_opcion(mopcion):
  menu_opcion()
  opcion = int(input("Seleccione una opcion: "))
  print(mopcion)
  print(opcion)
  caso_opcion(mopcion,opcion)

# %%
#def caso_opcion(self, mopcion,opcion):
class caso_opcion:
  def __init__(self, mopcion,opcion):
    
    #*****************
    #      LBPH
    #*****************
    if mopcion== 1 and opcion == 1: #(1. LBPH, 1. Perros)
      print('1. LBPH, 1. Perros')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Perros' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Perros/ROSTRO_REDIMENSIONADO'#2

      anexo_archivo='LBPH_Perros'

      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))

       #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)
      
    elif mopcion== 1 and opcion == 2: #(1. LBPH, 2. Buscar Perro)
      print('1. LBPH, 2. Buscar Perro')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Perros_Entrada' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Buscar_perro/ROSTRO_REDIMENSIONADO'#2

      anexo_archivo='LBPH_Perros_Entrada'

      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))

      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)
      #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      
    elif mopcion== 1 and opcion == 3:  #(1. LBPH, 3. Gatos)

      print('1. LBPH, 3. Gatos')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Gatos' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Gatos/ROSTRO_REDIMENSIONADO'#2

      anexo_archivo='LBPH_Gatos'
    
      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))

      #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)

    elif mopcion== 1 and opcion == 4: #(1. LBPH, 4. Buscar Gato)
      print('1. LBPH, 4. Buscar Gato')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Gatos_Entrada' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Buscar_gato/ROSTRO_REDIMENSIONADO'#2

      anexo_archivo='LBPH_Gatos_Entrada'

      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))
      
       #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)
      
    elif mopcion== 1 and opcion == 5: #(1. LBPH, 1. LBPH, 5. Gatos QUERY)
      print('1. LBPH, 1. LBPH, 5. Gatos QUERY')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Gatos_QUERY' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Gatos_QUERY/ROSTRO_REDIMENSIONADO'#2 

      anexo_archivo='LBPH_Gatos_QUERY'

      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))
      
       #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)

    elif mopcion== 1 and opcion == 6: #(3. LBPH, 6. Perros QUERY)
      print('3. LBPH, 6. Perros QUERY')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Perros_QUERY/ROSTRO_REDIMENSIONADO'#2

      anexo_archivo='LBPH_Perros_QUERY'

      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))
      
       #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)

    else:
      #seleccion_opcion()
      print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
      print('Error: La opción ingresada de BUSQUEDA no esta dentro de las opciones, por favor vuelva a ingresar la opción')
      print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
      print('')
      print('')
      print('')
      seleccion_opcion()

# %%
def caso_menu(mopcion):
  if mopcion == 1:
    print('LPBH')
    seleccion_opcion(mopcion)
  else:
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    print('Error: La opción ingresada no esta dentro de las opciones, por favor vuelva a ingresar la opción')
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    print('')
    print('')
    seleccion_menu()

seleccion_menu()
# Out:
# ----------- Tesis U Catolica -----------
# ----------- Seleccione la tecnica a implementar -----------
# 1. LPBH
# -----------------------------------
# Seleccione una opcion: 1
# LPBH
# ----------- Medidas de similaridad -----------
# 1. Perros
# 2. Buscar Perro
# 3. Gatos
# 4. Buscar Gato
# 5. Gatos QUERY
# 6. Perros QUERY
# -----------------------------------
# Seleccione una opcion: 6
# 1
# 6
# 3. LBPH, 6. Perros QUERY
# False
# True
# path_redimensionadas2.Resultados_Preprocesamiento/Perros_QUERY/ROSTRO_REDIMENSIONADO
# path_resultado4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY
# anexo_archivoLBPH_Perros_QUERY
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/14_Cody_Pug/14_Cody_Pug_6.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/3_Bandit_Pug/3_Bandit_Pug_4.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/9_Bella_Theresa_Husky/9_Bella_Theresa_Husky_3.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/7_Bailey_Husky/7_Bailey_Husky_4.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/4_Apolo_Husky/4_Apolo_Husky_9.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/8_Bella_Husky/8_Bella_Husky_3.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/13_Dakota_Husky/13_Dakota_Husky_5.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/2_AmericanBully_Yoko/2_AmericanBully_Yoko_6.jpeg
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/12_Blaxter_Pitbull/12_Blaxter_Pitbull_3.jpeg
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/6_Bella_Kappel_Husky/6_Bella_Kappel_Husky_4.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/15_Clara_Pug/15_Clara_Pug_5.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/27_Doris_Pug/27_Doris_Pug_5.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/28_Dina_BorderCollie/28_Dina_BorderCollie_1.jpeg
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/16_Chesnut_Criollo/16_Chesnut_Criollo_6.jpeg
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/18_Chloe_Pug/18_Chloe_Pug_1.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/19_Bu_chan_Pug/19_Bu_chan_Pug_3.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/23_Dante_Mixto/23_Dante_Mixto_2.jpeg
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/21_Capitan_PastorCollie/21_Capitan_PastorCollie_8.jpeg
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/20_Canela_Criollo/20_Canela_Criollo_1.jpeg
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY/25_Dakota_CNC_Husky/25_Dakota_CNC_Husky_1.png
# Filename 4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY