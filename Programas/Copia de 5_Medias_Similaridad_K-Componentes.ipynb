# %% [markdown]
# *** MEDIDAS DE SIMILARIDAD ***

# %% [markdown]
# Datos del Drive.
# 1. Conexión y permisos con el drive personal

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# 2. Ubicación de las carpetas a utilizar

# %%
#%cd /content/gdrive/My Drive/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento/
# %cd /content/gdrive/My Drive/0_Desarrollo_Tesis/
# Out:
# /content/gdrive/.shortcut-targets-by-id/13aHaot6tbm7SROiS_JzQgfDtjZ_DM4PH/0_Desarrollo_Tesis

# %% [markdown]
# 3. Listar la lista del contenido de la ruta

# %%
# !ls /content/gdrive/My\ Drive/0_Desarrollo_Tesis/*

# %% [markdown]
# *** FUNCION DISTANCIA EUCLIDIANA***

# %%
import math
import numpy as np
#imagen_entrada, imagen_dataset
def distancia_euclidiana(x,y):
  suma=0
  for j in range(256):
    numx=(int(x[0:255][j]))
    numy=(int(y[0:255][j]))
    elevado=pow(numx-numy,2)
    suma=elevado+suma
  return math.sqrt(suma)

# %% [markdown]
# *** FUNCION Distancia Manhattan ***

# %%
import math
import numpy as np
#imagen_entrada, imagen_dataset
def distancia_manhattan(x,y):
  suma=0
  for j in range(256):
    numx=(int(x[0:255][j]))
    numy=(int(y[0:255][j]))
    valor_absoluto=abs(numx-numy)
    suma=suma+valor_absoluto
  return suma

# %% [markdown]
# *** Lectura de Caracteristicas ***

# %%
import numpy as np
import pandas as pd

def funcion_lectura_carpetas(ARRAY_DATASET,ARRAY_IMAGEN, MEDIDA): #, MEDIDA PENDIENTE
  print("························")
  print(ARRAY_DATASET[3])
  print(ARRAY_IMAGEN[3])


  
  if(os.path.isfile(ARRAY_DATASET[0]) and os.path.isfile(ARRAY_DATASET[1]) and os.path.isfile(ARRAY_DATASET[0])
     and os.path.isfile(ARRAY_IMAGEN[0]) and os.path.isfile(ARRAY_IMAGEN[1]) and os.path.isfile(ARRAY_IMAGEN[2])):
    
    #Imagen de test
    lectura_histograma_dataset = pd.read_csv(ARRAY_IMAGEN[0], header= None)
    rutas_dataset = pd.read_csv(ARRAY_IMAGEN[1],header=None ,dtype=str)
    rutas_dataset_original = pd.read_csv(ARRAY_IMAGEN[2],header=None ,dtype=str)
    
    #Imagen de Datasets 
    lectura_histograma_test = pd.read_csv(ARRAY_DATASET[0], header= None)
    rutas_test = pd.read_csv(ARRAY_DATASET[1],header=None ,dtype=str)
    rutas_test_original = pd.read_csv(ARRAY_DATASET[2],header=None ,dtype=str)

    print('//////////////////////')
    print('rutas_dataset')
    print(len(rutas_dataset))
    print('rutas_test')
    print(len(rutas_test))
    print('//////////////////////')
    '''
    if MEDIDA==1:
      print('1. distancia_euclidiana')
      resultado=[]
      #print(len(lab_dataset))
      
      for i in range(len(rutas_test)):
        dataset_imagen_test=lectura_histograma_test[0:255][(i):(i+1)]
        #Resultados de la distancia euclidiana
        #resultado.append(distancia_euclidiana(entrada_imagen,dataset_imagen))
        #CREACION DE ARCHIVOS CSV CON LAS CARACTERISTICAS
        histograma_caracteristicas="10.Medidas_Similaridad/"+anexo_archivo+"/histograma_caracteristicas.csv"
        for j in range(len(rutas_dataset)):
          dataset_imagen_dataset=lectura_histograma_dataset[0:255][(j):(j+1)]
          #Resultados de la distancia euclidiana
          #resultado.append(distancia_euclidiana(dataset_imagen_test,dataset_imagen_dataset))

      '''
   


  '''
  #print(lectura_histograma[0:255][0:1]) #[columna][fila]
  entrada_imagen=lectura_histograma[0:255][0:1]

  if MEDIDA==1:
    print('distancia_euclidiana')
    resultado=[]
    #print(len(lab_dataset))
    
    for i in range(len(lab_dataset)):
      dataset_imagen=lectura_histograma_dataset[0:255][(i):(i+1)]
      #Resultados de la distancia euclidiana
      resultado.append(distancia_euclidiana(entrada_imagen,dataset_imagen))
    
    
   
  
  elif MEDIDA==2:
    print('distancia_manhattan')
    resultado=[]
    for i in range(len(lab_dataset)):
      dataset_imagen=lectura_histograma_dataset[0:255][(i):(i+1)]
      #Resultados de la distancia_manhattan
      resultado.append(distancia_manhattan(entrada_imagen,dataset_imagen))

  else:
    print('Ninguna medida')

  '''

# %% [markdown]
# *** IMAGEN RESULTADO ***

# %%
#imagen resultado que tiene mas similitud con la imagen de entrada.
import cv2
import numpy as np
from matplotlib import pyplot as plt
def imagen_imprime(imagen):
  img = cv2.imread(imagen)
  img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(img_cvt)
  plt.show()

# %% [markdown]
# *** Preguntas de flujo ***

# %%
# Importar Librerias

import dlib, cv2, os
from imutils import face_utils
import numpy as np
import matplotlib.pyplot as plt
import os
from skimage import io, color
import cv2 as cv

# %%
def menu_tesis():
  print("-----------        Tesis U Catolica      -----------")
  print("----------- ** Medidas de similaridad ** -----------")
  print("----- Seleccione la tecnica por la que desea implementar -----")
  print("1. Eigen - (Gatos - GatosQUERY)")
  print("2. Eigen - (Gatos - Buscar Gato)")
  print("3. Eigen - (Perros - PerrosQUERY)")
  print("4. Eigen - (Perros - Buscar Perro)")
  
  print("-----------------------------------")

def menu_opcion():
  print("----------- Medidas de similaridad -----------")
  print("1. Distancia Euclidiana")
  print("2. Distancia Manhattan")
  print("-----------------------------------")

def seleccion_menu():
  menu_tesis()
  mopcion = int(input("Seleccione una opcion: "))
  caso_menu(mopcion)

def seleccion_opcion(mopcion):
  menu_opcion()
  opcion = int(input("Seleccione una opcion: "))
  #print(mopcion)
  #print(opcion)
  caso_opcion(mopcion,opcion)

# %%
def recorrer_kcomponentes(DATOS_UNO,DATOS_DOS, MEDIDA):
    print('*******************')
    print('DATOS_UNO : '+DATOS_UNO)
    print('DATOS_DOS : '+DATOS_DOS)
    print('MEDIDA : '+ str(MEDIDA))
    print('*******************')

    print('********* DATOS_UNO **********')
    #*******************************
    # DATASET ENTRENAMIENTO GATOS O PERROS
    #*******************************
    for kcom in os.listdir(DATOS_DOS): 
      print("kcom "+kcom)
      archivo1=DATOS_DOS + '/' + kcom+ '/' +'histograma_ruta_redimensionada.csv'
      archivo2=DATOS_DOS + '/' + kcom+ '/' +'histograma_caracteristicas.csv'
      archivo3=DATOS_DOS + '/' + kcom+ '/' +'histograma_ruta_eigen.csv'
      #ARRAY_DATASET=['histograma_ruta_redimensionada.csv', 'histograma_caracteristicas.csv', 'histograma_ruta_eigen.csv', kcom]
      ARRAY_DATASET=[archivo1, archivo2, archivo3, kcom]
      

      #*******************************
      # DATASET PRUEBA GATOS O PERROS
      #*******************************
      for k2com in os.listdir(DATOS_UNO):
        print("  ** k2com "+k2com)
        archivo_1=DATOS_UNO + '/' + k2com+ '/' +'histograma_ruta_redimensionada.csv'
        archivo_2=DATOS_UNO + '/' + k2com+ '/' +'histograma_caracteristicas.csv'
        archivo_3=DATOS_UNO + '/' + k2com+ '/' +'histograma_ruta_eigen.csv'
        ARRAY_DATASET2=[archivo_1, archivo_2, archivo_3, k2com]
        #ARRAY_DATASET2=['histograma_ruta_redimensionada.csv', 'histograma_caracteristicas.csv', 'histograma_ruta_eigen.csv',k2com]
        funcion_lectura_carpetas(ARRAY_DATASET,ARRAY_DATASET2, MEDIDA)
      
      '''
      for archivo in os.listdir(DATOS_UNO + '/' + kcom):
        #print('archivo: '+ archivo)
        ARRAY_DATASET.append(archivo)
      '''
      #print(ARRAY_DATASET)

    '''
    print('********* DATOS_DOS **********')
    for k2com in os.listdir(DATOS_DOS):
      #print('K : '+ k2com)
      ARRAY_DATASET2=[]
      for archivo2 in os.listdir(DATOS_DOS + '/' + k2com):
        #print('sujeto: '+ archivo)
        ARRAY_DATASET2.append(archivo2)
      print(ARRAY_DATASET2)

    MEDIDA=opcion
    #funcion_prueba(ARRAY_DATASET,ARRAY_IMAGEN, MEDIDA)
    '''

# %%
class caso_opcion:
  def __init__(self, mopcion,opcion):

    #*****************
    #      EIGEN
    #*****************

    if mopcion== 1 and opcion == 1: 
      print('1. Eigen - (Gatos - GatosQUERY), 1. Distancia Euclidiana')
      DATOS_UNO='5.Resultados_Histogramas/Eigen_Gatos'
      DATOS_DOS='5.Resultados_Histogramas/Eigen_Gatos_QUERY'
      MEDIDA=opcion
      recorrer_kcomponentes(DATOS_UNO,DATOS_DOS, MEDIDA)
      
    else:
      print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
      print('Error: La opción ingresada de BUSQUEDA no esta dentro de las opciones, por favor vuelva a ingresar la opción')
      print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
      print('')
      print('')
      print('')
      seleccion_opcion()

# %%
def caso_menu(mopcion):
  if mopcion == 1:
    print('1. Eigen - (Perros - PerrosQUERY)')
    seleccion_opcion(mopcion)
  else:
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    print('Error: La opción ingresada no esta dentro de las opciones, por favor vuelva a ingresar la opción')
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_141
# ························
# K_1
# K_141
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_142
# ························
# K_1
# K_142
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_143
# ························
# K_1
# K_143
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_144
# ························
# K_1
# K_144
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_145
# ························
# K_1
# K_145
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_146
# ························
# K_1
# K_146
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_147
# ························
# K_1
# K_147
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_148
# ························
# K_1
# K_148
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_149
# ························
# K_1
# K_149
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_150
# ························
# K_1
# K_150
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_151
# ························
# K_1
# K_151
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_152
# ························
# K_1
# K_152
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_153
# ························
# K_1
# K_153
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_154
# ························
# K_1
# K_154
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_155
# ························
# K_1
# K_155
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_156
# ························
# K_1
# K_156
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_157
# ························
# K_1
# K_157
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_158
# ························
# K_1
# K_158
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_159
# ························
# K_1
# K_159
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_160
# ························
# K_1
# K_160
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_161
# ························
# K_1
# K_161
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_162
# ························
# K_1
# K_162
# //////////////////////
# rutas_dataset
# 344
# rutas_test
# 108
# //////////////////////
#   ** k2com K_163
# ························
# K_1
# K_163
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-1cbb0b914e40> in <module>()
#      12     seleccion_menu()
#      13
# ---> 14 seleccion_menu()
#
# <ipython-input-10-81b023128a43> in seleccion_menu()
#      19   menu_tesis()
#      20   mopcion = int(input("Seleccione una opcion: "))
# ---> 21   caso_menu(mopcion)
#      22
#      23 def seleccion_opcion(mopcion):
#
# <ipython-input-15-1cbb0b914e40> in caso_menu(mopcion)
#       3   if mopcion == 1:
#       4     print('1. Eigen - (Perros - PerrosQUERY)')
# ----> 5     seleccion_opcion(mopcion)
#       6   else:
#       7     print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
#
# <ipython-input-10-81b023128a43> in seleccion_opcion(mopcion)
#      26   #print(mopcion)
#      27   #print(opcion)
# ---> 28   caso_opcion(mopcion,opcion)
#
# <ipython-input-14-3f68472e0c2b> in __init__(self, mopcion, opcion)
#      12       DATOS_DOS='5.Resultados_Histogramas/Eigen_Gatos_QUERY'
#      13       MEDIDA=opcion
# ---> 14       recorrer_kcomponentes(DATOS_UNO,DATOS_DOS, MEDIDA)
#      15
#      16     else:
#
# <ipython-input-11-a5581ccb8688> in recorrer_kcomponentes(DATOS_UNO, DATOS_DOS, MEDIDA)
#      29         ARRAY_DATASET2=[archivo_1, archivo_2, archivo_3, k2com]
#      30         #ARRAY_DATASET2=['histograma_ruta_redimensionada.csv', 'histograma_caracteristicas.csv', 'histograma_ruta_eigen.csv',k2com]
# ---> 31         funcion_lectura_carpetas(ARRAY_DATASET,ARRAY_DATASET2, MEDIDA)
#      32
#      33       '''
#
# <ipython-input-5-934b515a8984> in funcion_lectura_carpetas(ARRAY_DATASET, ARRAY_IMAGEN, MEDIDA)
#      15     lectura_histograma_dataset = pd.read_csv(ARRAY_IMAGEN[0], header= None)
#      16     rutas_dataset = pd.read_csv(ARRAY_IMAGEN[1],header=None ,dtype=str)
# ---> 17     rutas_dataset_original = pd.read_csv(ARRAY_IMAGEN[2],header=None ,dtype=str)
#      18
#      19     #Imagen de Datasets
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# KeyboardInterrupt:
