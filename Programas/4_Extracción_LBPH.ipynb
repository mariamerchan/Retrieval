# %% [markdown]
# *** EXTRACCION DE CARACTETISTICAS LBPH ***

# %% [markdown]
# Datos del Drive.
# 1. Conexión y permisos con el drive personal

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# 2. Ubicación de las carpetas a utilizar

# %%
#%cd /content/gdrive/My Drive/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento/
# %cd /content/gdrive/My Drive/0_Desarrollo_Tesis/
# Out:
# /content/gdrive/My Drive/0_Desarrollo_Tesis

# %% [markdown]
# 3. Listar la lista del contenido de la ruta

# %%
# !ls /content/gdrive/My\ Drive/0_Desarrollo_Tesis/*
# Out:
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/caracteristicas_globales_dataset.csv'
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/histogram_dataset.csv'
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/0.Detector Convolucional':
# dogHeadDetector.dat
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/0. Estadisticas':
# 1.Datasets.csv	   2.Resultados_Preprocesamiento.csv	 4.Dataset_control.csv
# 1.Datasets.gsheet  3.Resultados_ext_caracteristicas.csv  Conteo_X_Imagen
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/10. Documentación':
#  Cronogramas   Documento	  Guias			    Links.docx
#  Dialogos     'Estado del arte'  'Investigación de Temas'
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/11.Presentaciones':
# 'Conceptos Web.pptx'   Invarianza.pptx	 Tesis
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/1.Programas_Funcionando':
#  0.Estadisticas.ipynb
#  1_Renombrar_imagenes.ipynb
# '2_Preprocesamiento COMPLETO.ipynb'
# '2_Preprocesamiento COMPLETO_QUERY.ipynb'
# '2_Preprocesamiento CSV.ipynb'
#  2_Preprocesamiento.ipynb
#  2_Preprocesamiento_MANUALES_REDIMENSIONADAS.ipynb
#  3_Extracción_Eigen.ipynb
#  3_Extracción_Eigen_V1.ipynb
#  4_Extracción_LBPH.ipynb
#  4_Extracción_LBPH_K.ipynb
#  4_Extracción_LBPH_v1.ipynb
# '5.1. Conteo de Imagenes por carpeta.ipynb'
#  5_Medias_Similaridad.ipynb
#  5_Medias_Similaridad_K-Componentes.ipynb
#  6_Medias_Desempeño.ipynb
# 'Copia de 2_Preprocesamiento.ipynb'
# 'Copia de 5_Medias_Similaridad.ipynb'
# 'Copia de 5_Medias_Similaridad_K-Componentes_14052021_2.ipynb'
# 'Copia de 5_Medias_Similaridad_K-Componentes_14052021.ipynb'
# 'Copia de 5_Medias_Similaridad_K-Componentes_Anexos.ipynb'
# 'Copia de 5_Medias_Similaridad_K-Componentes.ipynb'
# 'Copia de Copia de retireval (1).ipynb'
# 'Copia de Copia de retireval.ipynb'
# 'Copia de distancia_euclidiana.ipynb'
# 'Copia de Eigen.ipynb'
# 'Copia de retireval.ipynb'
#  distancia_euclidiana.ipynb
#  Eigen.ipynb
#  euclidean_distance.ipynb
#  Fisher.ipynb
#  LBPH.ipynb
#  Preprocesamiento_ENTRADA
#  Preprocesamiento.ipynb
#  __pycache__
#  retireval.ipynb
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/2.Resultados_Preprocesamiento':
# Ancho_Alto_RNC.csv  Buscar_perro  Gatos_QUERY  Perros
# Buscar_gato	    Gatos	  Gatos_V1     Perros_QUERY
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/3.Datasets':
# 1.DATASET_PERROS	2.DATASET_GATOS        3.DATASET_ENTRADA_PERROS
# 1.DATASET_PERROS_QUERY	2.DATASET_GATOS_QUERY  4.DATASET_ENTRADA_GATOS
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/3.Datasets_original':
# 1.DATASET_PERROS  2.DATASET_GATOS_V1	    4.DATASET_ENTRADA_GATOS
# 2.DATASET_GATOS   3.DATASET_ENTRADA_PERROS
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/4.Resultados_ext_caracteristicas':
# Eigen_Gatos	     Eigen_Perros_Entrada  LBPH_Gatos_QUERY
# Eigen_Gatos_Entrada  Eigen_Perros_QUERY    LBPH_Perros
# Eigen_Gatos_QUERY    LBPH_Gatos		   LBPH_Perros_Entrada
# Eigen_Perros	     LBPH_Gatos_Entrada    LBPH_Perros_QUERY
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/5.Resultados_Histogramas':
# Eigen_Gatos	     Eigen_Perros_Entrada  LBPH_Gatos_QUERY
# Eigen_Gatos_Entrada  Eigen_Perros_QUERY    LBPH_Perros
# Eigen_Gatos_QUERY    LBPH_Gatos		   LBPH_Perros_Entrada
# Eigen_Perros	     LBPH_Gatos_Entrada    LBPH_Perros_QUERY
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/6.Dataset_control':
# Varios
#
# '/content/gdrive/My Drive/0_Desarrollo_Tesis/7.Medidas_Similaridad':
# K_1_K_1  K_1_K_2

# %% [markdown]
# ***FUNCION HISTOGRAMA***

# %%
def histogram(imgGRAY):
    #histograma
    hist = cv.calcHist([imgGRAY],[0],None,[256],[0,256])
    # return the histogram
    return hist.flatten()

# %%
# CODIGO DE PRUEBAS

def funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo):
  print("path_EXTRACCION"+path_EXTRACCION)
  print("path_REDIMENSIONADO"+path_REDIMENSIONADO)
  print("anexo_archivo"+anexo_archivo)

# %% [markdown]
# *** LBPH ***

# %%
def getLBPimage(gray_image):
  ### Step 0: Step 0: Convert an image to grayscale
  gray_image = cv2.cvtColor(gray_image, cv2.COLOR_BGR2GRAY)
  imgLBP = np.zeros_like(gray_image)
  neighboor = 3 
  for ih in range(0,imgLBP.shape[0] - neighboor):
      for iw in range(0,imgLBP.shape[1] - neighboor):
          ### Step 1: 3 by 3 pixel
          img          = gray_image[ih:ih+neighboor,iw:iw+neighboor]
          center       = img[1,1]
          img01        = (img >= center)*1.0
          img01_vector = img01.T.flatten()
          ### Step 2: **Binary operation**:
          img01_vector = np.delete(img01_vector,4)
          ### Step 3: Decimal: Convert the binary operated values to a digit.
          where_img01_vector = np.where(img01_vector)[0]
          if len(where_img01_vector) >= 1:
              num = np.sum(2**where_img01_vector)
          else:
              num = 0
          imgLBP[ih+1,iw+1] = num
  return(imgLBP)

# %%
import matplotlib.pyplot as plt 
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

from skimage import io, color
import cv2 as cv


def extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo):

  path_redimensionadas=path_REDIMENSIONADO #Imagen redimensionada a color
  path_resultado=path_EXTRACCION  #Imagen Eigen
  os.makedirs(path_resultado, exist_ok=True)

  print("path_redimensionadas"+path_redimensionadas)
  print("path_resultado"+path_resultado)
  print("anexo_archivo"+anexo_archivo)

  #CREACION DE ARCHIVOS CSV CON LAS CARACTERISTICAS
  os.makedirs("5.Resultados_Histogramas/"+anexo_archivo+"/LBPH", exist_ok=True)
  histograma_caracteristicas="5.Resultados_Histogramas/"+anexo_archivo+"/LBPH/histograma_caracteristicas.csv"
  histograma_ruta_redimensionada="5.Resultados_Histogramas/"+anexo_archivo+"/LBPH/histograma_ruta_redimensionada.csv"
  histograma_ruta_LBPH="5.Resultados_Histogramas/"+anexo_archivo+"/LBPH/histograma_ruta_LBPH.csv"

  #Guarda la ruta de imagen REDIMENSIONADA
  archivo_ruta_redimensionada= open(histograma_ruta_redimensionada, "w+") 
  #Caracteristicas imagenes LBP a Histogramas
  archivo_histograma= open(histograma_caracteristicas, "w+") 
  #Guarda la ruta de imagen LBPH
  archivo_ruta_LBPH= open(histograma_ruta_LBPH, "w+")


  #For que recorre las carpetas(sujetos) del path
  contador = 0
  for aa in os.listdir(path_redimensionadas):
    #For que recorre la imagen de cada carpeta(sujeto)
    for f in os.listdir(path_redimensionadas + '/' + aa):
      contador = contador + 1
      #aa Carpeta del sujeto 
      #f Nombre de la imagen del sujeto
      #Ruta de la imagen
      imgPath = path_redimensionadas + '/' + aa + '/' + f

      #Guarda la ruta de imagen REDIMENSIONADA
      archivo_ruta_redimensionada.write(imgPath)
      archivo_ruta_redimensionada.write("\n")

      #Abrir Imagen (Lee la imagen en formtado BGR)
      imgBGR=''
      imgBGR = cv2.imread(imgPath)
      '''
      fig = plt.figure(figsize=(20,8))
      ax  = fig.add_subplot(1,3,1)
      ax.imshow(imgBGR)
      '''
      
      #*****************
      #    LBPH
      #*****************
      imgLBP    = getLBPimage(imgBGR)
      #Guarda imagenes imagenes con cuadros
      os.makedirs(path_resultado+ '/'+ aa, exist_ok=True)
      filename=(path_resultado + '/' + aa + '/' + f) 
      print("Filename "+filename)
      cv2.imwrite(filename, imgLBP.reshape(180,180)) 

      #Guarda la ruta de imagen EIGEN
      archivo_ruta_LBPH.write(filename)
      archivo_ruta_LBPH.write("\n")

      #*****************
      #    Histograma
      #*****************
      fv_hist = histogram(imgLBP)
      i=0
      archivo_histograma.write(filename)
      archivo_histograma.write(",")

      for b in fv_hist:
        i=i+1
        archivo_histograma.write("%.20f" % float(b))
        if(i<=(len(fv_hist)-1)):
          archivo_histograma.write(",")
      archivo_histograma.write("\n")

# %%
# Importar Librerias

import dlib, cv2, os
from imutils import face_utils
import numpy as np
import matplotlib.pyplot as plt
import os
from skimage import io, color
import cv2 as cv

# %%
def menu_tesis():
  print("----------- Tesis U Catolica -----------")
  print("----------- Seleccione la tecnica a implementar -----------")
  print("1. LPBH")
  print("-----------------------------------")

# %%
def menu_opcion():
  print("----------- Medidas de similaridad -----------")
  print("1. Perros")
  print("2. Buscar Perro")
  print("3. Gatos")
  print("4. Buscar Gato")
  print("5. Gatos QUERY")
  print("6. Perros QUERY")
  print("-----------------------------------")

# %%
def seleccion_menu():
  menu_tesis()
  mopcion = int(input("Seleccione una opcion: "))
  caso_menu(mopcion)

# %%
def seleccion_opcion(mopcion):
  menu_opcion()
  opcion = int(input("Seleccione una opcion: "))
  print(mopcion)
  print(opcion)
  caso_opcion(mopcion,opcion)

# %%
#def caso_opcion(self, mopcion,opcion):
class caso_opcion:
  def __init__(self, mopcion,opcion):
    
    #*****************
    #      LBPH
    #*****************
    if mopcion== 1 and opcion == 1: #(1. LBPH, 1. Perros)
      print('1. LBPH, 1. Perros')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Perros' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Perros/ROSTRO_REDIMENSIONADO'#2

      anexo_archivo='LBPH_Perros'

      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))

       #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)
      
    elif mopcion== 1 and opcion == 2: #(1. LBPH, 2. Buscar Perro)
      print('1. LBPH, 2. Buscar Perro')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Perros_Entrada' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Buscar_perro/ROSTRO_REDIMENSIONADO'#2

      anexo_archivo='LBPH_Perros_Entrada'

      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))

      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)
      #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      
    elif mopcion== 1 and opcion == 3:  #(1. LBPH, 3. Gatos)

      print('1. LBPH, 3. Gatos')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Gatos' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Gatos/ROSTRO_REDIMENSIONADO'#2

      anexo_archivo='LBPH_Gatos'
    
      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))

      #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)

    elif mopcion== 1 and opcion == 4: #(1. LBPH, 4. Buscar Gato)
      print('1. LBPH, 4. Buscar Gato')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Gatos_Entrada' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Buscar_gato/ROSTRO_REDIMENSIONADO'#2

      anexo_archivo='LBPH_Gatos_Entrada'

      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))
      
       #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)
      
    elif mopcion== 1 and opcion == 5: #(1. LBPH, 1. LBPH, 5. Gatos QUERY)
      print('1. LBPH, 1. LBPH, 5. Gatos QUERY')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Gatos_QUERY' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Gatos_QUERY/ROSTRO_REDIMENSIONADO'#2 

      anexo_archivo='LBPH_Gatos_QUERY'

      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))
      
       #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)

    elif mopcion== 1 and opcion == 6: #(3. LBPH, 6. Perros QUERY)
      print('3. LBPH, 6. Perros QUERY')
      path_EXTRACCION = '4.Resultados_ext_caracteristicas/LBPH_Perros_QUERY' #1
      path_REDIMENSIONADO='2.Resultados_Preprocesamiento/Perros_QUERY/ROSTRO_REDIMENSIONADO'#2

      anexo_archivo='LBPH_Perros_QUERY'

      print(os.path.isdir(path_EXTRACCION))
      print(os.path.isdir(path_REDIMENSIONADO))
      
       #funcion_prueba(path_EXTRACCION,path_REDIMENSIONADO,anexo_archivo)
      extraccion_imagen_LBPH(path_EXTRACCION,path_REDIMENSIONADO, anexo_archivo)

    else:
      #seleccion_opcion()
      print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
      print('Error: La opción ingresada de BUSQUEDA no esta dentro de las opciones, por favor vuelva a ingresar la opción')
      print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
      print('')
      print('')
      print('')
      seleccion_opcion()

# %%
def caso_menu(mopcion):
  if mopcion == 1:
    print('LPBH')
    seleccion_opcion(mopcion)
  else:
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    print('Error: La opción ingresada no esta dentro de las opciones, por favor vuelva a ingresar la opción')
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
